# %% [markdown]
# <a href="https://colab.research.google.com/github/Ductin168/BLE-Smart-Hub-Remote/blob/main/HK151_SPE_Nebula.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Simulation of a multiple dentist chair/minor surgery system.

# %% [markdown]
# # 1. Team work declaration
#
# ## Team Nebula
# | Student           | Id      |
# |-------------------|---------|
# | Bùi Thanh Tú            | 2213837 |
# | Đỗ Ôn Trí Quân          | 2212783 |
# | Hồ Đức Tín              | 2213486 |
# | Hồ Ngọc Anh Tuấn        | 2213768 |
# | Huỳnh Minh Nhật         | 2212390 |
# | Nguyễn Văn Minh         | 2212069 |
# | Nông Văn Trung          | 2213707 |
# | Phan Huy Trung          | 2213709 |
# ## Workmap declaration
#
# | Last name | Student ID | Design Role | Dev Role | Eval Role | Report Role | Ass1 work description (details in text)  | Rating | week 2 outcome | week 3 outcome | week 4 outcome  |
# |-----------|------------|-------------|----------|-----------|-------------|------------------------------------------|-----------------|----------------|----------------|-----------------|
# | Tú        | 2213837 | yes | no | no | no | Design system   | A/B/C  |                |                |                 |
# | Quân        | 2212783 | no | yes  | no | yes |          |     A/B/C           |                |                |                 |
# | Tín        | 2213486 | no | yes | no  | yes/no      |                                          | A/B/C           |                |                |                 |
# | Tuấn        | 2213768 | no | no | yes | yes/no      |                                          | A/B/C           |                |                |                 |
# | Nhật        | 2212390 | no | no | yes | yes/no      |                                          | A/B/C           |                |                |                 |
# | Minh        | 2212069 | yes    | no   | no  |yes | Design system | A/B/C           |                |                |                 |
# | Trung          |2213707| yes | no | no | no | Design system |                 |                |                |                 |
# | Trung  | 2213709 | no  | no | yes |  yes/no      |       |        |         |            |             |

# %% [markdown]
# # 2.System design
#
# ## System Performance Steps
#
# ### 1. Define Goal and System
# ####1.1. State goal
# Hệ thống được lựa chọn để mô phỏng lại hàng đợi của một cơ sở nha khoa, mục tiêu là đánh giá hiệu suất phục vụ, khám chữa bệnh của từng hàng đợi tương ứng với từng khu vực được chia trong cơ sở bằng mô hình hàng đợi M/M/c. Các mục tiêu chính bao gồm:
# - Mô phỏng: Tạo một mô phỏng chi tiết về hệ thống hàng đợi của cơ sở nha khoa, với nhiều khu vực khác nhau.
# - Phân tích: Phân tích kết quả dựa trên mô phỏng thu được như số lượng công việc hiện thực được trong quá trình mô phỏng, thông tin chi tiết, yếu tố khác nhau ảnh hưởng tới sự lưu thông của bệnh nhân trong cơ sở cũng như thời gian phải chờ đợi
# - Đánh giá: Đánh giá toàn diện hệ thống được mô phỏng để qua đó tìm hiểu hiệu suất đạt được của hệ thống, hiệu quả sử dụng các server.
# ####1.2. Define system
# #####1.2.1. Giới thiệu các thành phần hệ thống
# Một cơ sở nha khoa chuyên điều trị khám răng thông thường và các tiểu phẫu nha (minor surgery) được mô phỏng theo mô hình hàng đợi M/M/c, gồm các khu vực chính sau:
#
# Khu vực tiếp (Reception Queing):
# -   Chức năng: Bệnh nhân đến đăng ký, khai báo triệu chứng, phân loại loại dịch vụ (khám thường, cạo vôi, nhổ răng tiểu phẫu, nội nha, v.v.), in số thứ tự và hướng dẫn tới khu vực tiếp theo.
# -   Nhân sự: Lễ tân/điều dưỡng phụ trách phân loại, hẹn phòng, in vé, kiểm tra bảo hiểm (BHYT) sơ bộ.
# -   Quy trình đầu: Đây là điểm vào hệ thống — thời điểm bắt đầu mô phỏng cho từng bệnh nhân.
#
# Khu vực sàn lọc / tiểu phẫu (Pre-op / Testing Queing)
# -   Chức năng: Những bệnh nhân có chỉ định cần xét nghiệm (ví dụ: huyết học, đông máu) hoặc cần sàng lọc tiền phẫu (hỏi tiền sử, đo huyết áp) trước khi thực hiện thủ thuật. Một số dịch vụ khám thông thường không cần qua bước này.
# -   Nhân sự: Điều dưỡng, kỹ thuật viên xét nghiệm.
# -   Lưu ý: Chỉ một phần bệnh nhân (theo xát suất) được chuyển đến khu này.
#
# Khu vực khám / điều trị (Dental treatment / Minor surgery Queuing)
# -   Chức năng: Khu chính gồm nhiều ghế nha (multiple dentist chair) / phòng nhỏ cho điều trị và tiểu phẩu. Bệnh nhân chờ tới lượt ghế/BS khám, thực hiện can thiệp nha hoặc tiểu phẫu (ví dụ nhổ răng phức tạp, khâu mềm ). Sau khi khám/tiểu phẫu, bác sĩ có thể kê đơn thuốc hoặc chỉ định tái khám.
# -   Nhân sự: Bác sĩ nha khoa / thầy thuốc (các server trong mô hình M/M/c), trợ thủ nha khoa, y tá hỗ trợ phẫu thuật.
#
# Khu vực thanh toán và nhận thuốc (Payment / Pharmacy Queuing)
# -   Chức năng: Thanh toán dịch vụ, kiểm tra BHYT chính thức, phát thuốc theo đơn. Sau khi hoàn tất thanh toán và nhận thuốc, bệnh nhân rời hệ thống — kết thúc mô phỏng.
# ##### 1.2.2. Các giả sử của hệ thống
#
# Để thực hiện mô phỏng và đánh giá hiệu, ta đặt các giả sử và ràng buộc sau cho mỗi hàng đợi:
# Quy trình đến (Arrival Process)
# -   Bệnh nhân đến trung tâm theo một quá trình Poisson với tốc độ trung bình λ (số bệnh nhân/đơn vị thời gian). Thời gian giữa các lần đến là biến ngẫu nhiên độc lập, phân phối mũ (Exponential).
# -   Tại thời điểm bệnh nhân bước vào Reception được coi là bắt đầu quan sát/mô phỏng cho bệnh nhân đó.
# Thời gian phục vụ (Service time)
# -   Thời gian phục vụ tại mỗi server (lễ tân, kỹ thuật viên xét nghiệm, bác sĩ/ghế nha, thu ngân, dược sĩ) được giả sử là các biến ngẫu nhiên độc lập, phân phối mũ với trung bình 1/μi khác nhau tùy khu vực i.
# -   Thời gian khử khuẩn/chuẩn bị ghế cũng được coi là thời gian phục vụ (có thể mô hình hóa như là một server riêng hoặc gộp vào thời gian rời giường).
# Mô hình hàng đợi (System Capacity & Discipline)
# -   Mỗi khu vực tuân theo mô hình M/M/c (c servers) với sức chứa hệ thống là vô hạn (infinite capacity waiting room).
# -   Nguyên tắc phục vụ là FCFS (First Come, First Served) trong mỗi queue. (Có thể mở rộng sau này bằng ưu tiên cho trường hợp cấp cứu — nếu muốn, mô phỏng thêm lớp ưu tiên).
# Quy tắc chuyển tuyến (Routing & Probabilities)
# -   Sau Reception, bệnh nhân được chuyển tới khu Testing với xác suất *P*test (tùy loại dịch vụ). Ngược lại, với xác suất 1 − *P*test bệnh nhân đi thẳng tới khu khám.
# -   Sau khám: với xác suất *P*surgery bệnh nhân cần tiểu phẫu (thời gian phục vụ lớn hơn trung bình), với xác suất khác là khám/điều trị thông thường. Một số ca sau phẫu thuật vào Recovery với xác suất *P*recovery.
# -   Sau khi hoàn tất (khám/tiểu phẫu và recovery nếu có), bệnh nhân sẽ được chuyển tới Payment.
#
# Sức chứa hệ thống
# -   Hệ thống giả sử không giới hạn số lượng bệnh nhân chờ (infinite buffer), vì mục tiêu là đo tải và thời gian chờ.
# Quy tắc khác và phạm vi mô phỏng
# -   Mô phỏng chỉ bắt đầu khi bệnh nhân vào Reception; các hoạt động ngoài (hẹn, gọi điện nhắc lịch, v.v.) nằm ngoài phạm vi.
# -   Mô phỏng kết thúc khi bệnh nhân đã hoàn tất thanh toán và nhận thuốc.
# -   Các biến cố hiếm như tai biến nặng, chuyển viện cấp cứu, hoặc chậm trễ do thiếu thiết bị chuyên sâu được coi là ngoài phạm vi.
# -   Không mô phỏng hành vi cá nhân phức tạp như rời hàng (balking) hoặc hủy hẹn giữa chừng (reneging) ban đầu.
# ##### 1.2.3. Mô hình hệ thống
# [![model.png](https://i.postimg.cc/vHk971dr/DGHNHT-drawio-2.png)](https://postimg.cc/rKGKMwss)
# #### 1.3. Đặc tả thông số mô hình
# * Đối với đề tài hệ thống xếp hàng của một nha khoa, nhóm triển khai bằng các Kendall's notation. Mô hình được nhóm sử dụng sẽ là M/M/c.
# * Thời gian bệnh nhân đến (Arrival process): Đối với mô phỏng đây sẽ là thời gian bệnh nhân bắt đầu đến quầy tiếp tân để lấy số báo danh cho việc khám. Thời gian giữa các hàng đợi là độc lập, ngẫu nhiên và tuân theo phân phối mũ với giá trị M(Markovian).
# * Thời gian phục vụ (service times): Đây là thời gian khám, chữa bệnh cho bệnh nhân tuân theo nguyên tắc hệ số mũ với giá trị M. Do đó, thời gian khám chữa bệnh cũng độc lập, ngẫu nhiên.
# * Số lượng server: Là số lượng các thành phần hay đơn vị của các phòng ban nhầm thực hiện khám, tiểu phẩu, thanh toán viện phí cho bệnh nhân. Đối với mô hình này là c với c > 1.
# * Sức chứa hệ thống (System Capacity): Đây là tổng số bệnh nhân tối đa hệ thống có thể tiếp nhận. Đối với bài mô hình này là vô hạn.
# * Kích thước nguồn (population size): Đây là kích thước nguồn khách. Đối với mô phỏng này là vô hạn.
# * Quy tắc hàng đợi: Đây là quy ước cách hệ thống giải quyết vấn đề các hàng đợi hay bệnh nhân. Đối với hệ thống phòng khám nha khoa sẽ là FCFS( First Come, First Served).
# * Hệ thống mô tả quá trình 1 bệnh nhân thực hiện lấy số thứ tự từ quầy tiếp tân đến khi hoàn thành việc thanh toán viện phí. Trong đó, bệnh nhân có thể được luân chuyển giữa các phòng khám, tiểu phẫu hay lấy thuốc ngẫu nhiên.
# * Bênh cạnh đó mô hình có thêm thực hiện đặt lịch thực hiện tiểu phẩu sau khi khám.
# ### 2. Service and Outcomes
# #### 2.1. Services
# Dựa trên các thành phần và giả sử đã đề cập, các dịch vụ do hệ thống cung cấp bao gồm:
# - Khu vực tiếp nhận, bệnh nhân được lấy số thứ tự để chờ. Tại đây bệnh nhân được nhận số thứ tự để chờ đợi, nhân viên lễ tân (điều dưỡng) sẽ tư vấn về nhu cầu kiểm tra, khám chữa và điều trị của bệnh nhân, hướng dẫn họ đến khu vực phù hợp.
# - Khi vào khu vực khám bệnh, bệnh nhân được dẫn đến các phòng khám tương ứng với vấn đề của mình hoặc ưu tiên đến khu vực xét nghiệm nếu có yêu cầu. Việc lựa chọn loại hình khám là ngẫu nhiên với tỷ lệ phân bố sau:
#   + Bệnh nhân chọn khám bệnh A (không cần xét nghiệm), lúc này họ sẽ tiến đến hàng đợi khám chữa bệnh (Medical Examination Queuing) với tỷ lệ xảy ra là a.
#   + Bệnh nhân chọn khám bệnh B (yêu cầu xét nghiệm trước), họ sẽ được chuyển đến hàng đợi xét nghiệm (Testing Queuing). Sau khi hoàn tất xét nghiệm, bệnh nhân được tiếp tục chuyển sang hàng đợi khám chữa bệnh (Medical Examination Queuing) với tỷ lệ xảy ra là b.
# - Tại hàng đợi khám chữa bệnh (Medical Examination Queuing), bệnh nhân được phân bổ đến bác sĩ phù hợp dựa trên chỉ định ban đầu. Quy trình tiếp theo diễn ra theo 2 hướng:
#   + Bệnh nhân có thể trở lại để kiểm tra một vấn đề khác với tỉ lệ c.
#   + Sau khi hoàn thành, bệnh nhân không cần khám thêm và di chuyển trực tiếp đến hàng đợi thanh toán cùng nhận thuốc (Paying Queuing) với tỉ lệ d.
# - Khi đã kết thúc quy trình khám, bệnh nhân đến khu vực thanh toán và nhận thuốc (Payment Queuing). Sau khi lấy được đơn thuốc theo chỉ định của bác sĩ, bệnh nhân được coi là hoàn tất và rời khỏi hệ thống.
# #### 2.2 Outcomes
# Từ các dịch vụ khám chữa bệnh do hệ thống này cung cấp, có nhiều kết quả có thể xảy ra như sau:
# - Ở khu vực tiếp đón: Bệnh nhân nhận được phiếu hẹn thành công và di chuyển vào khu vực khám, dẫn đến hai khả năng chính:
#   + Chuyển sang khu vực xét nghiệm để thực hiện thủ tục cần thiết.
#   + Tiến thẳng đến khu vực khám chữa bệnh mà không cần bước trung gian.
#
#   Các điểm nghẽn tiềm ẩn: Hệ thống bị quá tải do số lượng bệnh nhân dồn dập, dẫn đến không thể tiếp nhận thêm; hoặc bệnh nhân không hài lòng với lời tư vấn và quyết định rời đi.
# - Ở khu vực khám chữa bệnh: Sau khi hoàn tất buổi khám, bệnh nhân sẽ đối mặt với hai lựa chọn:
#   + Di chuyển trực tiếp đến khu vực thanh toán và nhận thuốc.
#   + Mong muốn kiểm tra thêm vấn đề sức khỏe khác, nên quay lại hàng đợi để chờ lượt tiếp theo.
# - Ngoài ra, bệnh nhân có nguy cơ phải chờ đợi kéo dài trước khi được phục vụ, gây ảnh hưởng đến trải nghiệm tổng thể.
# ### 3. Select Metrics
# - Thời gian chờ đợi lấy số thứ tự.
# - Thời gian chờ đợi để được xét nghiệm.
# - Thời gian chờ đợi bác sĩ đến khám.
# - Thời gian chờ đợi thanh toán và lấy thuốc.
# - Số lượng bệnh nhân hoàn thành việc khám chữa bệnh (áp dụng cho mỗi hàng đợi).
# ### 4. List System Parameters
# Hệ thống sẽ dùng các thông số để thay đổi thay đổi hành vi cũng nhưng số lượng bệnh nhân được tạo ra, thời gian và hiệu suất phục vụ của các đơn vị:
#
#   **Workload parameter**
#
# * Số lượng server(c): Như đã nhắc đến trong mục [1.3](#scrollTo=vZhnVr2dBMuW), thông số ảnh hưởng tới tốc độ phục vụ của hệ thống và khả năng xử lý đồng thời. Đối với mô hình của bệnh viện nha khoa sẽ là:
#     - Số lượng lễ tân tại khu vực tiếp nhận.
#     - Số lượng bác sĩ thực hiện khám bệnh cũng như xét nghiệm, chụp X quang tại phòng khám. Mỗi bác sĩ sẽ tương ứng với một phòng khám trong mô hình sẽ tương ứng với 1 phòng khám bệnh.
#     - Số lượng phòng tiểu phẫu dùng để thực hiện tiễu phẫu cho các bệnh nhân.
#     - Số lượng điều dưỡng tại khu vực thanh toán và lấy thuốc.
# * Arrival Rate ($ \lambda $): Tỷ lệ bệnh nhân đến hệ thống khám chữa bệnh, là số lượng bệnh nhân trung bình trên một đơn vị thời gian.
# * Service Rate (μ): Tỷ lệ phục vụ bệnh nhân của hệ thống, đây là giá trị ảnh hưởng đến thời gian thực hiện tiểu phẩu, khám bệnh của một bệnh nhân.
#
#   Các parameter trên đều có thể thay đổi để tạo dựng các tình huống (workload) khác nhau cho việc mô phỏng. Các tình huống này, đối với mô hình nha khoa sẽ là thời điểm quá tải, trống hay là tiền đề đặt ra quy mô của bệnh viện.
#
# * Thời gian khách hàng phải chờ đợi: Đây là thông số để đánh giá tượng quan giữa hiệu năng làm việc của hệ thông bệnh viện so với tỷ lệ bệnh nhân chờ khám. Thông số sẽ được đánh giá ở từng khu vực và được tính tổng thể nhằm cho biết các đơn vị cần cải thiện và hiệu suất cải thiện.
#
# **System parameter**
#
# * Thời gian phục vụ: Đây sẽ là thời gian để một bệnh nhân dùng dịch vụ khám chữa bệnh tại từng hàng đợi và tổng thể trong một lần đến khám chữa bệnh tại bệnh viện. (Không tính thời gian kể từ lúc bệnh nhân đặt lịch thực hiện tiểu phẫu).
# ### 5. List Factors to Study
# - Service Rate ($\mu$)
# - Arrival Rate (λ)
# - Thời gian phục vụ tại từng hàng đợi.
# - Số lượng server cần cho mỗi hàng đợi.
# - Maximum Queue Length (K), độ dài hàng đợi tối đa cho mỗi hàng đợi.
# - Mức độ quá tải dựa vào arrival rate.
# ### 6. Evaluation Technique
# - Analytical modeling.
# - Simulation với thư viện SimPy.
# ### 7. Select Workload
# Để đánh giá mô hình hoạt động của một bệnh viện nha khoa có các dịch vụ khám, thực hiện tiểu phẫu, lấy thuốc nhóm sẽ lựa chọn workload dựa trên các yêu tố sau:
# * Phân tích hiệu năng của mô hình bênh viện dựa trên của model được thiết lặp thông qua các parameter.
# * Phân tích tập trung vào thời gian chờ đợi cũng như thời gian giải quyết các hàng đợi (bệnh nhân).
# * Thực hiện đối chiếu kết quả mô phỏng với mô hình lý thuyết M/M/c.
# * Nghiên cứu ra mô hình hiệu quả tương quan theo số nguồn lực của một bệnh viện đối với số lượng bệnh nhân.

# %% [markdown]
# ## System Component/Module description

# %% [markdown]
# # 3. System Implementation

# %% [markdown]
# Install prerequisite library

# %%
pip install simpy
# Out:
# Collecting simpy
#   Downloading simpy-4.1.1-py3-none-any.whl.metadata (6.1 kB)
# Downloading simpy-4.1.1-py3-none-any.whl (27 kB)
# Installing collected packages: simpy
# Successfully installed simpy-4.1.1

# %% [markdown]
# Import necessary libraries

# %%
# Imports for the simulation core
import simpy
import random
import pandas as pd
from typing import Callable, Optional, Dict, Any

# %%
# Simulation parameters

# Global RNG seed (set to None for non-deterministic runs)
RANDOM_SEED = 123

# Simulation control
SIM_TIME = 20000.0   # total simulated time
WARMUP_TIME = 0.0   # optional warmup period if need to avoid transient period

# Toggle for printing real-time events
ENABLE_TRACE = True

def trace(msg: str):
    """Print if tracing is enabled."""
    if ENABLE_TRACE:
        print(msg)

# %% [markdown]
# Hook interfaces for metrics and analytics

# %%
# Simple hook/callback structure so metrics/analytics can attach functions.
# Each hook is optional (set to a callable that accepts specific args), or None.

# Hook signatures (expected):
#   on_arrival(patient_id:int, now:float, node_name:str)
#   on_service_start(patient_id:int, now:float, node_name:str)
#   on_service_end(patient_id:int, now:float, node_name:str)
#   on_departure(patient_id:int, now:float)

# Default no-op callbacks:
def _noop(*_, **__):
    return None

class Callbacks:
    def __init__(self,
                 on_arrival: Optional[Callable[[int, float, str], Any]] = None,
                 on_service_start: Optional[Callable[[int, float, str], Any]] = None,
                 on_service_end: Optional[Callable[[int, float, str], Any]] = None,
                 on_departure: Optional[Callable[[int, float], Any]] = None):
        self.on_arrival = on_arrival or _noop
        self.on_service_start = on_service_start or _noop
        self.on_service_end = on_service_end or _noop
        self.on_departure = on_departure or _noop

# %% [markdown]
# Queue node

# %%
class QueueNode:
    """
    Generic M/M/c node (simulation core) with optional tracing.
    """
    def __init__(self, env, name, n_servers, service_rate, callbacks=None):
        self.env = env
        self.name = name
        self.n_servers = int(n_servers)
        self.service_rate = float(service_rate)
        self.resource = simpy.Resource(env, capacity=self.n_servers)
        self.callbacks = callbacks or Callbacks()

    def _draw_service_time(self):
        return random.expovariate(self.service_rate)

    def serve(self, patient_id):
        arrival_to_node = self.env.now
            # NEW: notify metrics collector
        try:
            self.callbacks.on_arrival(patient_id, arrival_to_node, self.name)
        except:
            pass
        trace(f"[t={self.env.now:.2f}] Patient {patient_id} ARRIVED at {self.name} queue.")

        with self.resource.request() as req:
            yield req
            start = self.env.now

            trace(f"[t={start:.2f}] Patient {patient_id} STARTS service at {self.name} (servers busy={self.resource.count}).")

            # Callbacks
            try:
                self.callbacks.on_service_start(patient_id, start, self.name)
            except:
                pass

            service_duration = self._draw_service_time()
            yield self.env.timeout(service_duration)

            end = self.env.now

            trace(f"[t={end:.2f}] Patient {patient_id} FINISHES service at {self.name}. Duration={service_duration:.2f}")

            # Callbacks
            try:
                self.callbacks.on_service_end(patient_id, end, self.name)
            except:
                pass

# %% [markdown]
# Build simulation system

# %%
def build_system(
    env: simpy.Environment,
    callbacks: Optional[Callbacks] = None,
    # THAM SỐ MỚI – CHO PHÉP THAY ĐỔI TẠI CHỖ
    arrival_rate=0.3,
    mu_reception=0.5, mu_testing=0.4, mu_exam=0.3, mu_payment=0.6,
    c_reception=2, c_testing=1, c_exam=3, c_payment=1
) -> Dict[str, QueueNode]:
    """
    Xây hệ thống với tất cả tham số có thể thay đổi.
    """
    callbacks = callbacks or Callbacks()

    nodes = {
        "reception": QueueNode(env, "reception", c_reception, mu_reception, callbacks),
        "testing":   QueueNode(env, "testing",   c_testing,   mu_testing,   callbacks),
        "exam":      QueueNode(env, "exam",      c_exam,      mu_exam,      callbacks),
        "payment":   QueueNode(env, "payment",   c_payment,   mu_payment,   callbacks),
    }

    # Lưu lại λ để arrival_generator dùng (vì nó đọc global ARRIVAL_RATE)
    global ARRIVAL_RATE
    ARRIVAL_RATE = arrival_rate

    return nodes

# %% [markdown]
# Main simulation logic (patients process)

# %%
def patient_process(env, patient_id, nodes, callbacks=None):
    callbacks = callbacks or Callbacks()
    trace(f"\n=== Patient {patient_id} ENTERS system at t={env.now:.2f} ===")
    try:
        callbacks.on_arrival(patient_id, env.now, "system_entry")
    except:
        pass

    # 1. Reception
    trace(f"Patient {patient_id} going to RECEPTION.")
    yield env.process(nodes["reception"].serve(patient_id))

    # 2. Routing: testing or straight to exam
    if random.random() < P_TEST:
        trace(f"Patient {patient_id} routed to TESTING.")
        yield env.process(nodes["testing"].serve(patient_id))
    else:
        trace(f"Patient {patient_id} SKIPS testing and goes to EXAM.")

    # 3. Examination, possibly multiple times (feedback loop)
    while True:
        trace(f"Patient {patient_id} entering EXAMINATION.")
        yield env.process(nodes["exam"].serve(patient_id))

        if random.random() < P_REEXAM:
            trace(f"Patient {patient_id} requires RE-EXAM. Returning to EXAM queue.")
        else:
            break

    # 4. Payment
    trace(f"Patient {patient_id} going to PAYMENT.")
    yield env.process(nodes["payment"].serve(patient_id))

    trace(f"=== Patient {patient_id} LEAVES system at t={env.now:.2f} ===\n")

    try:
        callbacks.on_departure(patient_id, env.now)
    except:
        pass

# %% [markdown]
# Arrival generator

# %%
def arrival_generator(env: simpy.Environment, nodes: Dict[str, QueueNode],
                      callbacks: Optional[Callbacks] = None, max_arrivals: Optional[int] = None):
    """
    Generates arrivals according to Poisson process (exponential inter-arrival times).
    If max_arrivals is provided, stops after generating that many patients.
    """
    callbacks = callbacks or Callbacks()
    patient_id = 0
    while True:
        # draw inter-arrival time
        inter = random.expovariate(ARRIVAL_RATE)
        yield env.timeout(inter)

        # spawn patient process
        env.process(patient_process(env, patient_id, nodes, callbacks))
        patient_id += 1

        if max_arrivals is not None and patient_id >= max_arrivals:
            break

# %% [markdown]
# Run simulation

# %%
def run_simulation(sim_time: float = SIM_TIME, callbacks: Optional[Callbacks] = None,
                   warmup: float = WARMUP_TIME, max_arrivals: Optional[int] = None, seed: Optional[int] = RANDOM_SEED):
    """
    Build env, nodes, start arrival generator, run for sim_time, return env and nodes.
    - callbacks: optional Callbacks instance (metrics team can pass theirs)
    - max_arrivals: optional cap on number of arrivals (alternate stopping condition)
    - seed: RNG seed for reproducibility (None for random)
    """
    if seed is not None:
        random.seed(seed)

    env = simpy.Environment()
    nodes = build_system(env, callbacks=callbacks)

    # start arrivals
    env.process(arrival_generator(env, nodes, callbacks=callbacks, max_arrivals=max_arrivals))

    # run
    env.run(until=sim_time)
    return env, nodes

# Example run (no metrics hooked)
if __name__ == "__main__":
    env, nodes = run_simulation(sim_time=200.0, seed=RANDOM_SEED)
    print("Simulation finished (no metrics attached). Node servers and rates:")
    for name, node in nodes.items():
        print(f" - {name}: servers={node.n_servers}, mu={node.service_rate}")
# Out:
# === Patient 0 ENTERS system at t=0.18 ===
# Patient 0 going to RECEPTION.
# [t=0.18] Patient 0 ARRIVED at reception queue.
# [t=0.18] Patient 0 STARTS service at reception (servers busy=1).
#
# === Patient 1 ENTERS system at t=0.48 ===
# Patient 1 going to RECEPTION.
# [t=0.48] Patient 1 ARRIVED at reception queue.
# [t=0.48] Patient 1 STARTS service at reception (servers busy=2).
#
# === Patient 2 ENTERS system at t=0.86 ===
# Patient 2 going to RECEPTION.
# [t=0.86] Patient 2 ARRIVED at reception queue.
#
# === Patient 3 ENTERS system at t=0.99 ===
# Patient 3 going to RECEPTION.
# [t=0.99] Patient 3 ARRIVED at reception queue.
# [t=1.23] Patient 0 FINISHES service at reception. Duration=1.05
# Patient 0 SKIPS testing and goes to EXAM.
# Patient 0 entering EXAMINATION.
# [t=1.23] Patient 0 ARRIVED at exam queue.
# [t=1.23] Patient 2 STARTS service at reception (servers busy=2).
# [t=1.23] Patient 0 STARTS service at exam (servers busy=1).
# [t=1.81] Patient 0 FINISHES service at exam. Duration=0.58
# Patient 0 going to PAYMENT.
# [t=1.81] Patient 0 ARRIVED at payment queue.
# [t=1.81] Patient 0 STARTS service at payment (servers busy=1).
# [t=2.48] Patient 0 FINISHES service at payment. Duration=0.68
# === Patient 0 LEAVES system at t=2.48 ===
#
#
# === Patient 4 ENTERS system at t=3.55 ===
# Patient 4 going to RECEPTION.
# [t=3.55] Patient 4 ARRIVED at reception queue.
#
# === Patient 5 ENTERS system at t=4.49 ===
# Patient 5 going to RECEPTION.
# [t=4.49] Patient 5 ARRIVED at reception queue.
#
# === Patient 6 ENTERS system at t=4.50 ===
# Patient 6 going to RECEPTION.
# [t=4.50] Patient 6 ARRIVED at reception queue.
# [t=5.05] Patient 2 FINISHES service at reception. Duration=3.82
# Patient 2 routed to TESTING.
# [t=5.05] Patient 2 ARRIVED at testing queue.
# [t=5.05] Patient 3 STARTS service at reception (servers busy=2).
# [t=5.05] Patient 2 STARTS service at testing (servers busy=1).
# [t=5.11] Patient 1 FINISHES service at reception. Duration=4.63
# Patient 1 SKIPS testing and goes to EXAM.
# Patient 1 entering EXAMINATION.
# [t=5.11] Patient 1 ARRIVED at exam queue.
# [t=5.11] Patient 4 STARTS service at reception (servers busy=2).
# [t=5.11] Patient 1 STARTS service at exam (servers busy=1).
# [t=5.23] Patient 2 FINISHES service at testing. Duration=0.18
# Patient 2 entering EXAMINATION.
# [t=5.23] Patient 2 ARRIVED at exam queue.
# [t=5.23] Patient 2 STARTS service at exam (servers busy=2).
# [t=5.55] Patient 2 FINISHES service at exam. Duration=0.32
# Patient 2 going to PAYMENT.
# [t=5.55] Patient 2 ARRIVED at payment queue.
# [t=5.55] Patient 2 STARTS service at payment (servers busy=1).
# [t=6.30] Patient 4 FINISHES service at reception. Duration=1.19
# Patient 4 routed to TESTING.
# [t=6.30] Patient 4 ARRIVED at testing queue.
# [t=6.30] Patient 5 STARTS service at reception (servers busy=2).
# [t=6.30] Patient 4 STARTS service at testing (servers busy=1).
#
# === Patient 7 ENTERS system at t=6.41 ===
# Patient 7 going to RECEPTION.
# [t=6.41] Patient 7 ARRIVED at reception queue.
# [t=6.87] Patient 3 FINISHES service at reception. Duration=1.82
# Patient 3 SKIPS testing and goes to EXAM.
# Patient 3 entering EXAMINATION.
# [t=6.87] Patient 3 ARRIVED at exam queue.
# [t=6.87] Patient 6 STARTS service at reception (servers busy=2).
# [t=6.87] Patient 3 STARTS service at exam (servers busy=2).
#
# === Patient 8 ENTERS system at t=7.44 ===
# Patient 8 going to RECEPTION.
# [t=7.44] Patient 8 ARRIVED at reception queue.
# [t=8.15] Patient 2 FINISHES service at payment. Duration=2.60
# === Patient 2 LEAVES system at t=8.15 ===
#
# [t=8.27] Patient 3 FINISHES service at exam. Duration=1.40
# Patient 3 going to PAYMENT.
# [t=8.27] Patient 3 ARRIVED at payment queue.
# [t=8.27] Patient 3 STARTS service at payment (servers busy=1).
# [t=8.43] Patient 4 FINISHES service at testing. Duration=2.13
# Patient 4 entering EXAMINATION.
# [t=8.43] Patient 4 ARRIVED at exam queue.
# [t=8.43] Patient 4 STARTS service at exam (servers busy=2).
# [t=9.80] Patient 6 FINISHES service at reception. Duration=2.93
# Patient 6 SKIPS testing and goes to EXAM.
# Patient 6 entering EXAMINATION.
# [t=9.80] Patient 6 ARRIVED at exam queue.
# [t=9.80] Patient 7 STARTS service at reception (servers busy=2).
# [t=9.80] Patient 6 STARTS service at exam (servers busy=3).
# [t=9.84] Patient 3 FINISHES service at payment. Duration=1.56
# === Patient 3 LEAVES system at t=9.84 ===
#
# [t=10.55] Patient 7 FINISHES service at reception. Duration=0.76
# Patient 7 SKIPS testing and goes to EXAM.
# Patient 7 entering EXAMINATION.
# [t=10.55] Patient 7 ARRIVED at exam queue.
# [t=10.55] Patient 8 STARTS service at reception (servers busy=2).
# [t=10.93] Patient 4 FINISHES service at exam. Duration=2.50
# Patient 4 going to PAYMENT.
# [t=10.93] Patient 4 ARRIVED at payment queue.
# [t=10.93] Patient 7 STARTS service at exam (servers busy=3).
# [t=10.93] Patient 4 STARTS service at payment (servers busy=1).
# [t=11.14] Patient 5 FINISHES service at reception. Duration=4.84
# Patient 5 SKIPS testing and goes to EXAM.
# Patient 5 entering EXAMINATION.
# [t=11.14] Patient 5 ARRIVED at exam queue.
# [t=11.49] Patient 6 FINISHES service at exam. Duration=1.69
# Patient 6 going to PAYMENT.
# [t=11.49] Patient 6 ARRIVED at payment queue.
# [t=11.49] Patient 5 STARTS service at exam (servers busy=3).
# [t=11.99] Patient 8 FINISHES service at reception. Duration=1.44
# Patient 8 SKIPS testing and goes to EXAM.
# Patient 8 entering EXAMINATION.
# [t=11.99] Patient 8 ARRIVED at exam queue.
# [t=12.76] Patient 4 FINISHES service at payment. Duration=1.83
# === Patient 4 LEAVES system at t=12.76 ===
#
# [t=12.76] Patient 6 STARTS service at payment (servers busy=1).
# [t=12.81] Patient 6 FINISHES service at payment. Duration=0.05
# === Patient 6 LEAVES system at t=12.81 ===
#
#
# === Patient 9 ENTERS system at t=12.83 ===
# Patient 9 going to RECEPTION.
# [t=12.83] Patient 9 ARRIVED at reception queue.
# [t=12.83] Patient 9 STARTS service at reception (servers busy=1).
# [t=12.97] Patient 1 FINISHES service at exam. Duration=7.86
# Patient 1 going to PAYMENT.
# [t=12.97] Patient 1 ARRIVED at payment queue.
# [t=12.97] Patient 8 STARTS service at exam (servers busy=3).
# [t=12.97] Patient 1 STARTS service at payment (servers busy=1).
# [t=13.23] Patient 9 FINISHES service at reception. Duration=0.40
# Patient 9 routed to TESTING.
# [t=13.23] Patient 9 ARRIVED at testing queue.
# [t=13.23] Patient 9 STARTS service at testing (servers busy=1).
# [t=14.25] Patient 9 FINISHES service at testing. Duration=1.03
# Patient 9 entering EXAMINATION.
# [t=14.25] Patient 9 ARRIVED at exam queue.
# [t=14.32] Patient 7 FINISHES service at exam. Duration=3.39
# Patient 7 going to PAYMENT.
# [t=14.32] Patient 7 ARRIVED at payment queue.
# [t=14.32] Patient 9 STARTS service at exam (servers busy=3).
# [t=14.57] Patient 9 FINISHES service at exam. Duration=0.25
# Patient 9 going to PAYMENT.
# [t=14.57] Patient 9 ARRIVED at payment queue.
# [t=14.76] Patient 1 FINISHES service at payment. Duration=1.79
# === Patient 1 LEAVES system at t=14.76 ===
#
# [t=14.76] Patient 7 STARTS service at payment (servers busy=1).
# [t=15.17] Patient 5 FINISHES service at exam. Duration=3.68
# Patient 5 going to PAYMENT.
# [t=15.17] Patient 5 ARRIVED at payment queue.
# [t=16.18] Patient 7 FINISHES service at payment. Duration=1.42
# === Patient 7 LEAVES system at t=16.18 ===
#
# [t=16.18] Patient 9 STARTS service at payment (servers busy=1).
# [t=16.53] Patient 9 FINISHES service at payment. Duration=0.35
# === Patient 9 LEAVES system at t=16.53 ===
#
# [t=16.53] Patient 5 STARTS service at payment (servers busy=1).
# [t=16.68] Patient 5 FINISHES service at payment. Duration=0.15
# === Patient 5 LEAVES system at t=16.68 ===
#
#
# === Patient 10 ENTERS system at t=17.50 ===
# Patient 10 going to RECEPTION.
# [t=17.50] Patient 10 ARRIVED at reception queue.
# [t=17.50] Patient 10 STARTS service at reception (servers busy=1).
# [t=17.53] Patient 10 FINISHES service at reception. Duration=0.03
# Patient 10 SKIPS testing and goes to EXAM.
# Patient 10 entering EXAMINATION.
# [t=17.53] Patient 10 ARRIVED at exam queue.
# [t=17.53] Patient 10 STARTS service at exam (servers busy=2).
# [t=18.40] Patient 10 FINISHES service at exam. Duration=0.87
# Patient 10 going to PAYMENT.
# [t=18.40] Patient 10 ARRIVED at payment queue.
# [t=18.40] Patient 10 STARTS service at payment (servers busy=1).
# [t=20.54] Patient 10 FINISHES service at payment. Duration=2.14
# === Patient 10 LEAVES system at t=20.54 ===
#
#
# === Patient 11 ENTERS system at t=20.80 ===
# Patient 11 going to RECEPTION.
# [t=20.80] Patient 11 ARRIVED at reception queue.
# [t=20.80] Patient 11 STARTS service at reception (servers busy=1).
# [t=21.14] Patient 8 FINISHES service at exam. Duration=8.16
# Patient 8 going to PAYMENT.
# [t=21.14] Patient 8 ARRIVED at payment queue.
# [t=21.14] Patient 8 STARTS service at payment (servers busy=1).
# [t=22.84] Patient 11 FINISHES service at reception. Duration=2.04
# Patient 11 SKIPS testing and goes to EXAM.
# Patient 11 entering EXAMINATION.
# [t=22.84] Patient 11 ARRIVED at exam queue.
# [t=22.84] Patient 11 STARTS service at exam (servers busy=1).
# [t=23.72] Patient 11 FINISHES service at exam. Duration=0.89
# Patient 11 going to PAYMENT.
# [t=23.72] Patient 11 ARRIVED at payment queue.
# [t=26.68] Patient 8 FINISHES service at payment. Duration=5.54
# === Patient 8 LEAVES system at t=26.68 ===
#
# [t=26.68] Patient 11 STARTS service at payment (servers busy=1).
# [t=27.01] Patient 11 FINISHES service at payment. Duration=0.33
# === Patient 11 LEAVES system at t=27.01 ===
#
#
# === Patient 12 ENTERS system at t=28.80 ===
# Patient 12 going to RECEPTION.
# [t=28.80] Patient 12 ARRIVED at reception queue.
# [t=28.80] Patient 12 STARTS service at reception (servers busy=1).
# [t=29.97] Patient 12 FINISHES service at reception. Duration=1.18
# Patient 12 SKIPS testing and goes to EXAM.
# Patient 12 entering EXAMINATION.
# [t=29.97] Patient 12 ARRIVED at exam queue.
# [t=29.97] Patient 12 STARTS service at exam (servers busy=1).
# [t=30.12] Patient 12 FINISHES service at exam. Duration=0.15
# Patient 12 going to PAYMENT.
# [t=30.12] Patient 12 ARRIVED at payment queue.
# [t=30.12] Patient 12 STARTS service at payment (servers busy=1).
# [t=30.48] Patient 12 FINISHES service at payment. Duration=0.36
# === Patient 12 LEAVES system at t=30.48 ===
#
#
# === Patient 13 ENTERS system at t=44.87 ===
# Patient 13 going to RECEPTION.
# [t=44.87] Patient 13 ARRIVED at reception queue.
# [t=44.87] Patient 13 STARTS service at reception (servers busy=1).
# [t=45.74] Patient 13 FINISHES service at reception. Duration=0.87
# Patient 13 routed to TESTING.
# [t=45.74] Patient 13 ARRIVED at testing queue.
# [t=45.74] Patient 13 STARTS service at testing (servers busy=1).
#
# === Patient 14 ENTERS system at t=45.86 ===
# Patient 14 going to RECEPTION.
# [t=45.86] Patient 14 ARRIVED at reception queue.
# [t=45.86] Patient 14 STARTS service at reception (servers busy=1).
# [t=46.09] Patient 14 FINISHES service at reception. Duration=0.23
# Patient 14 routed to TESTING.
# [t=46.09] Patient 14 ARRIVED at testing queue.
# [t=47.17] Patient 13 FINISHES service at testing. Duration=1.42
# Patient 13 entering EXAMINATION.
# [t=47.17] Patient 13 ARRIVED at exam queue.
# [t=47.17] Patient 14 STARTS service at testing (servers busy=1).
# [t=47.17] Patient 13 STARTS service at exam (servers busy=1).
# [t=47.48] Patient 13 FINISHES service at exam. Duration=0.31
# Patient 13 going to PAYMENT.
# [t=47.48] Patient 13 ARRIVED at payment queue.
# [t=47.48] Patient 13 STARTS service at payment (servers busy=1).
# [t=47.49] Patient 13 FINISHES service at payment. Duration=0.01
# === Patient 13 LEAVES system at t=47.49 ===
#
#
# === Patient 15 ENTERS system at t=47.68 ===
# Patient 15 going to RECEPTION.
# [t=47.68] Patient 15 ARRIVED at reception queue.
# [t=47.68] Patient 15 STARTS service at reception (servers busy=1).
# [t=47.83] Patient 15 FINISHES service at reception. Duration=0.15
# Patient 15 SKIPS testing and goes to EXAM.
# Patient 15 entering EXAMINATION.
# [t=47.83] Patient 15 ARRIVED at exam queue.
# [t=47.83] Patient 15 STARTS service at exam (servers busy=1).
# [t=48.26] Patient 14 FINISHES service at testing. Duration=1.10
# Patient 14 entering EXAMINATION.
# [t=48.26] Patient 14 ARRIVED at exam queue.
# [t=48.26] Patient 14 STARTS service at exam (servers busy=2).
# [t=49.56] Patient 15 FINISHES service at exam. Duration=1.73
# Patient 15 going to PAYMENT.
# [t=49.56] Patient 15 ARRIVED at payment queue.
# [t=49.56] Patient 15 STARTS service at payment (servers busy=1).
#
# === Patient 16 ENTERS system at t=50.24 ===
# Patient 16 going to RECEPTION.
# [t=50.24] Patient 16 ARRIVED at reception queue.
# [t=50.24] Patient 16 STARTS service at reception (servers busy=1).
# [t=50.62] Patient 15 FINISHES service at payment. Duration=1.07
# === Patient 15 LEAVES system at t=50.62 ===
#
# [t=51.05] Patient 16 FINISHES service at reception. Duration=0.82
# Patient 16 SKIPS testing and goes to EXAM.
# Patient 16 entering EXAMINATION.
# [t=51.05] Patient 16 ARRIVED at exam queue.
# [t=51.05] Patient 16 STARTS service at exam (servers busy=2).
# [t=54.45] Patient 16 FINISHES service at exam. Duration=3.40
# Patient 16 going to PAYMENT.
# [t=54.45] Patient 16 ARRIVED at payment queue.
# [t=54.45] Patient 16 STARTS service at payment (servers busy=1).
#
# === Patient 17 ENTERS system at t=54.87 ===
# Patient 17 going to RECEPTION.
# [t=54.87] Patient 17 ARRIVED at reception queue.
# [t=54.87] Patient 17 STARTS service at reception (servers busy=1).
#
# === Patient 18 ENTERS system at t=56.68 ===
# Patient 18 going to RECEPTION.
# [t=56.68] Patient 18 ARRIVED at reception queue.
# [t=56.68] Patient 18 STARTS service at reception (servers busy=2).
# [t=57.40] Patient 17 FINISHES service at reception. Duration=2.53
# Patient 17 routed to TESTING.
# [t=57.40] Patient 17 ARRIVED at testing queue.
# [t=57.40] Patient 17 STARTS service at testing (servers busy=1).
# [t=57.60] Patient 17 FINISHES service at testing. Duration=0.20
# Patient 17 entering EXAMINATION.
# [t=57.60] Patient 17 ARRIVED at exam queue.
# [t=57.60] Patient 17 STARTS service at exam (servers busy=2).
# [t=57.61] Patient 18 FINISHES service at reception. Duration=0.93
# Patient 18 routed to TESTING.
# [t=57.61] Patient 18 ARRIVED at testing queue.
# [t=57.61] Patient 18 STARTS service at testing (servers busy=1).
# [t=58.04] Patient 16 FINISHES service at payment. Duration=3.59
# === Patient 16 LEAVES system at t=58.04 ===
#
# [t=59.44] Patient 18 FINISHES service at testing. Duration=1.83
# Patient 18 entering EXAMINATION.
# [t=59.44] Patient 18 ARRIVED at exam queue.
# [t=59.44] Patient 18 STARTS service at exam (servers busy=3).
#
# === Patient 19 ENTERS system at t=60.47 ===
# Patient 19 going to RECEPTION.
# [t=60.47] Patient 19 ARRIVED at reception queue.
# [t=60.47] Patient 19 STARTS service at reception (servers busy=1).
#
# === Patient 20 ENTERS system at t=60.99 ===
# Patient 20 going to RECEPTION.
# [t=60.99] Patient 20 ARRIVED at reception queue.
# [t=60.99] Patient 20 STARTS service at reception (servers busy=2).
# [t=62.01] Patient 18 FINISHES service at exam. Duration=2.57
# Patient 18 going to PAYMENT.
# [t=62.01] Patient 18 ARRIVED at payment queue.
# [t=62.01] Patient 18 STARTS service at payment (servers busy=1).
# [t=62.23] Patient 18 FINISHES service at payment. Duration=0.23
# === Patient 18 LEAVES system at t=62.23 ===
#
# [t=62.34] Patient 14 FINISHES service at exam. Duration=14.08
# Patient 14 going to PAYMENT.
# [t=62.34] Patient 14 ARRIVED at payment queue.
# [t=62.34] Patient 14 STARTS service at payment (servers busy=1).
# [t=62.60] Patient 19 FINISHES service at reception. Duration=2.13
# Patient 19 SKIPS testing and goes to EXAM.
# Patient 19 entering EXAMINATION.
# [t=62.60] Patient 19 ARRIVED at exam queue.
# [t=62.60] Patient 19 STARTS service at exam (servers busy=2).
# [t=63.55] Patient 14 FINISHES service at payment. Duration=1.21
# === Patient 14 LEAVES system at t=63.55 ===
#
# [t=63.99] Patient 20 FINISHES service at reception. Duration=2.99
# Patient 20 SKIPS testing and goes to EXAM.
# Patient 20 entering EXAMINATION.
# [t=63.99] Patient 20 ARRIVED at exam queue.
# [t=63.99] Patient 20 STARTS service at exam (servers busy=3).
# [t=64.20] Patient 20 FINISHES service at exam. Duration=0.21
# Patient 20 going to PAYMENT.
# [t=64.20] Patient 20 ARRIVED at payment queue.
# [t=64.20] Patient 20 STARTS service at payment (servers busy=1).
# [t=64.64] Patient 17 FINISHES service at exam. Duration=7.04
# Patient 17 going to PAYMENT.
# [t=64.64] Patient 17 ARRIVED at payment queue.
# [t=66.04] Patient 20 FINISHES service at payment. Duration=1.84
# === Patient 20 LEAVES system at t=66.04 ===
#
# [t=66.04] Patient 17 STARTS service at payment (servers busy=1).
# [t=68.00] Patient 19 FINISHES service at exam. Duration=5.40
# Patient 19 going to PAYMENT.
# [t=68.00] Patient 19 ARRIVED at payment queue.
#
# === Patient 21 ENTERS system at t=69.24 ===
# Patient 21 going to RECEPTION.
# [t=69.24] Patient 21 ARRIVED at reception queue.
# [t=69.24] Patient 21 STARTS service at reception (servers busy=1).
# [t=69.45] Patient 17 FINISHES service at payment. Duration=3.41
# === Patient 17 LEAVES system at t=69.45 ===
#
# [t=69.45] Patient 19 STARTS service at payment (servers busy=1).
# [t=70.06] Patient 19 FINISHES service at payment. Duration=0.60
# === Patient 19 LEAVES system at t=70.06 ===
#
# [t=71.45] Patient 21 FINISHES service at reception. Duration=2.21
# Patient 21 SKIPS testing and goes to EXAM.
# Patient 21 entering EXAMINATION.
# [t=71.45] Patient 21 ARRIVED at exam queue.
# [t=71.45] Patient 21 STARTS service at exam (servers busy=1).
# [t=71.55] Patient 21 FINISHES service at exam. Duration=0.10
# Patient 21 going to PAYMENT.
# [t=71.55] Patient 21 ARRIVED at payment queue.
# [t=71.55] Patient 21 STARTS service at payment (servers busy=1).
# [t=74.97] Patient 21 FINISHES service at payment. Duration=3.42
# === Patient 21 LEAVES system at t=74.97 ===
#
#
# === Patient 22 ENTERS system at t=82.36 ===
# Patient 22 going to RECEPTION.
# [t=82.36] Patient 22 ARRIVED at reception queue.
# [t=82.36] Patient 22 STARTS service at reception (servers busy=1).
# [t=82.65] Patient 22 FINISHES service at reception. Duration=0.30
# Patient 22 SKIPS testing and goes to EXAM.
# Patient 22 entering EXAMINATION.
# [t=82.65] Patient 22 ARRIVED at exam queue.
# [t=82.65] Patient 22 STARTS service at exam (servers busy=1).
#
# === Patient 23 ENTERS system at t=84.77 ===
# Patient 23 going to RECEPTION.
# [t=84.77] Patient 23 ARRIVED at reception queue.
# [t=84.77] Patient 23 STARTS service at reception (servers busy=1).
# [t=85.28] Patient 22 FINISHES service at exam. Duration=2.63
# Patient 22 going to PAYMENT.
# [t=85.28] Patient 22 ARRIVED at payment queue.
# [t=85.28] Patient 22 STARTS service at payment (servers busy=1).
# [t=85.81] Patient 22 FINISHES service at payment. Duration=0.53
# === Patient 22 LEAVES system at t=85.81 ===
#
#
# === Patient 24 ENTERS system at t=86.30 ===
# Patient 24 going to RECEPTION.
# [t=86.30] Patient 24 ARRIVED at reception queue.
# [t=86.30] Patient 24 STARTS service at reception (servers busy=2).
# [t=86.76] Patient 24 FINISHES service at reception. Duration=0.45
# Patient 24 SKIPS testing and goes to EXAM.
# Patient 24 entering EXAMINATION.
# [t=86.76] Patient 24 ARRIVED at exam queue.
# [t=86.76] Patient 24 STARTS service at exam (servers busy=1).
# [t=88.45] Patient 24 FINISHES service at exam. Duration=1.69
# Patient 24 going to PAYMENT.
# [t=88.45] Patient 24 ARRIVED at payment queue.
# [t=88.45] Patient 24 STARTS service at payment (servers busy=1).
# [t=88.59] Patient 24 FINISHES service at payment. Duration=0.14
# === Patient 24 LEAVES system at t=88.59 ===
#
#
# === Patient 25 ENTERS system at t=88.65 ===
# Patient 25 going to RECEPTION.
# [t=88.65] Patient 25 ARRIVED at reception queue.
# [t=88.65] Patient 25 STARTS service at reception (servers busy=2).
# [t=89.10] Patient 25 FINISHES service at reception. Duration=0.45
# Patient 25 SKIPS testing and goes to EXAM.
# Patient 25 entering EXAMINATION.
# [t=89.10] Patient 25 ARRIVED at exam queue.
# [t=89.10] Patient 25 STARTS service at exam (servers busy=1).
# [t=89.25] Patient 23 FINISHES service at reception. Duration=4.48
# Patient 23 routed to TESTING.
# [t=89.25] Patient 23 ARRIVED at testing queue.
# [t=89.25] Patient 23 STARTS service at testing (servers busy=1).
#
# === Patient 26 ENTERS system at t=89.39 ===
# Patient 26 going to RECEPTION.
# [t=89.39] Patient 26 ARRIVED at reception queue.
# [t=89.39] Patient 26 STARTS service at reception (servers busy=1).
#
# === Patient 27 ENTERS system at t=89.68 ===
# Patient 27 going to RECEPTION.
# [t=89.68] Patient 27 ARRIVED at reception queue.
# [t=89.68] Patient 27 STARTS service at reception (servers busy=2).
# [t=90.15] Patient 26 FINISHES service at reception. Duration=0.76
# Patient 26 SKIPS testing and goes to EXAM.
# Patient 26 entering EXAMINATION.
# [t=90.15] Patient 26 ARRIVED at exam queue.
# [t=90.15] Patient 26 STARTS service at exam (servers busy=2).
#
# === Patient 28 ENTERS system at t=91.07 ===
# Patient 28 going to RECEPTION.
# [t=91.07] Patient 28 ARRIVED at reception queue.
# [t=91.07] Patient 28 STARTS service at reception (servers busy=2).
# [t=91.23] Patient 27 FINISHES service at reception. Duration=1.54
# Patient 27 SKIPS testing and goes to EXAM.
# Patient 27 entering EXAMINATION.
# [t=91.23] Patient 27 ARRIVED at exam queue.
# [t=91.23] Patient 27 STARTS service at exam (servers busy=3).
# [t=91.32] Patient 23 FINISHES service at testing. Duration=2.08
# Patient 23 entering EXAMINATION.
# [t=91.32] Patient 23 ARRIVED at exam queue.
#
# === Patient 29 ENTERS system at t=93.62 ===
# Patient 29 going to RECEPTION.
# [t=93.62] Patient 29 ARRIVED at reception queue.
# [t=93.62] Patient 29 STARTS service at reception (servers busy=2).
# [t=94.16] Patient 28 FINISHES service at reception. Duration=3.08
# Patient 28 SKIPS testing and goes to EXAM.
# Patient 28 entering EXAMINATION.
# [t=94.16] Patient 28 ARRIVED at exam queue.
# [t=94.21] Patient 29 FINISHES service at reception. Duration=0.59
# Patient 29 SKIPS testing and goes to EXAM.
# Patient 29 entering EXAMINATION.
# [t=94.21] Patient 29 ARRIVED at exam queue.
# [t=95.60] Patient 27 FINISHES service at exam. Duration=4.37
# Patient 27 going to PAYMENT.
# [t=95.60] Patient 27 ARRIVED at payment queue.
# [t=95.60] Patient 23 STARTS service at exam (servers busy=3).
# [t=95.60] Patient 27 STARTS service at payment (servers busy=1).
# [t=95.67] Patient 26 FINISHES service at exam. Duration=5.52
# Patient 26 going to PAYMENT.
# [t=95.67] Patient 26 ARRIVED at payment queue.
# [t=95.67] Patient 28 STARTS service at exam (servers busy=3).
# [t=96.02] Patient 27 FINISHES service at payment. Duration=0.42
# === Patient 27 LEAVES system at t=96.02 ===
#
# [t=96.02] Patient 26 STARTS service at payment (servers busy=1).
# [t=96.12] Patient 28 FINISHES service at exam. Duration=0.45
# Patient 28 going to PAYMENT.
# [t=96.12] Patient 28 ARRIVED at payment queue.
# [t=96.12] Patient 29 STARTS service at exam (servers busy=3).
# [t=96.48] Patient 25 FINISHES service at exam. Duration=7.38
# Patient 25 going to PAYMENT.
# [t=96.48] Patient 25 ARRIVED at payment queue.
# [t=97.28] Patient 23 FINISHES service at exam. Duration=1.68
# Patient 23 going to PAYMENT.
# [t=97.28] Patient 23 ARRIVED at payment queue.
# [t=97.70] Patient 26 FINISHES service at payment. Duration=1.68
# === Patient 26 LEAVES system at t=97.70 ===
#
# [t=97.70] Patient 28 STARTS service at payment (servers busy=1).
#
# === Patient 30 ENTERS system at t=98.62 ===
# Patient 30 going to RECEPTION.
# [t=98.62] Patient 30 ARRIVED at reception queue.
# [t=98.62] Patient 30 STARTS service at reception (servers busy=1).
# [t=98.73] Patient 30 FINISHES service at reception. Duration=0.11
# Patient 30 SKIPS testing and goes to EXAM.
# Patient 30 entering EXAMINATION.
# [t=98.73] Patient 30 ARRIVED at exam queue.
# [t=98.73] Patient 30 STARTS service at exam (servers busy=2).
#
# === Patient 31 ENTERS system at t=99.06 ===
# Patient 31 going to RECEPTION.
# [t=99.06] Patient 31 ARRIVED at reception queue.
# [t=99.06] Patient 31 STARTS service at reception (servers busy=1).
# [t=99.68] Patient 28 FINISHES service at payment. Duration=1.98
# === Patient 28 LEAVES system at t=99.68 ===
#
# [t=99.68] Patient 25 STARTS service at payment (servers busy=1).
# [t=100.15] Patient 31 FINISHES service at reception. Duration=1.09
# Patient 31 SKIPS testing and goes to EXAM.
# Patient 31 entering EXAMINATION.
# [t=100.15] Patient 31 ARRIVED at exam queue.
# [t=100.15] Patient 31 STARTS service at exam (servers busy=3).
# [t=100.23] Patient 30 FINISHES service at exam. Duration=1.50
# Patient 30 going to PAYMENT.
# [t=100.23] Patient 30 ARRIVED at payment queue.
# [t=100.42] Patient 25 FINISHES service at payment. Duration=0.74
# === Patient 25 LEAVES system at t=100.42 ===
#
# [t=100.42] Patient 23 STARTS service at payment (servers busy=1).
# [t=101.33] Patient 29 FINISHES service at exam. Duration=5.21
# Patient 29 going to PAYMENT.
# [t=101.33] Patient 29 ARRIVED at payment queue.
# [t=101.55] Patient 31 FINISHES service at exam. Duration=1.40
# Patient 31 going to PAYMENT.
# [t=101.55] Patient 31 ARRIVED at payment queue.
#
# === Patient 32 ENTERS system at t=102.74 ===
# Patient 32 going to RECEPTION.
# [t=102.74] Patient 32 ARRIVED at reception queue.
# [t=102.74] Patient 32 STARTS service at reception (servers busy=1).
#
# === Patient 33 ENTERS system at t=102.96 ===
# Patient 33 going to RECEPTION.
# [t=102.96] Patient 33 ARRIVED at reception queue.
# [t=102.96] Patient 33 STARTS service at reception (servers busy=2).
# [t=103.29] Patient 23 FINISHES service at payment. Duration=2.86
# === Patient 23 LEAVES system at t=103.29 ===
#
# [t=103.29] Patient 30 STARTS service at payment (servers busy=1).
# [t=103.61] Patient 30 FINISHES service at payment. Duration=0.32
# === Patient 30 LEAVES system at t=103.61 ===
#
# [t=103.61] Patient 29 STARTS service at payment (servers busy=1).
# [t=103.81] Patient 32 FINISHES service at reception. Duration=1.07
# Patient 32 SKIPS testing and goes to EXAM.
# Patient 32 entering EXAMINATION.
# [t=103.81] Patient 32 ARRIVED at exam queue.
# [t=103.81] Patient 32 STARTS service at exam (servers busy=1).
# [t=104.97] Patient 29 FINISHES service at payment. Duration=1.36
# === Patient 29 LEAVES system at t=104.97 ===
#
# [t=104.97] Patient 31 STARTS service at payment (servers busy=1).
# [t=105.19] Patient 31 FINISHES service at payment. Duration=0.22
# === Patient 31 LEAVES system at t=105.19 ===
#
#
# === Patient 34 ENTERS system at t=105.27 ===
# Patient 34 going to RECEPTION.
# [t=105.27] Patient 34 ARRIVED at reception queue.
# [t=105.27] Patient 34 STARTS service at reception (servers busy=2).
#
# === Patient 35 ENTERS system at t=106.30 ===
# Patient 35 going to RECEPTION.
# [t=106.30] Patient 35 ARRIVED at reception queue.
# [t=106.49] Patient 33 FINISHES service at reception. Duration=3.54
# Patient 33 SKIPS testing and goes to EXAM.
# Patient 33 entering EXAMINATION.
# [t=106.49] Patient 33 ARRIVED at exam queue.
# [t=106.49] Patient 35 STARTS service at reception (servers busy=2).
# [t=106.49] Patient 33 STARTS service at exam (servers busy=2).
# [t=106.60] Patient 35 FINISHES service at reception. Duration=0.11
# Patient 35 routed to TESTING.
# [t=106.60] Patient 35 ARRIVED at testing queue.
# [t=106.60] Patient 35 STARTS service at testing (servers busy=1).
#
# === Patient 36 ENTERS system at t=107.59 ===
# Patient 36 going to RECEPTION.
# [t=107.59] Patient 36 ARRIVED at reception queue.
# [t=107.59] Patient 36 STARTS service at reception (servers busy=2).
# [t=108.13] Patient 33 FINISHES service at exam. Duration=1.64
# Patient 33 going to PAYMENT.
# [t=108.13] Patient 33 ARRIVED at payment queue.
# [t=108.13] Patient 33 STARTS service at payment (servers busy=1).
# [t=108.38] Patient 36 FINISHES service at reception. Duration=0.79
# Patient 36 SKIPS testing and goes to EXAM.
# Patient 36 entering EXAMINATION.
# [t=108.38] Patient 36 ARRIVED at exam queue.
# [t=108.38] Patient 36 STARTS service at exam (servers busy=2).
# [t=108.65] Patient 33 FINISHES service at payment. Duration=0.52
# === Patient 33 LEAVES system at t=108.65 ===
#
# [t=108.70] Patient 34 FINISHES service at reception. Duration=3.43
# Patient 34 routed to TESTING.
# [t=108.70] Patient 34 ARRIVED at testing queue.
# [t=108.73] Patient 35 FINISHES service at testing. Duration=2.13
# Patient 35 entering EXAMINATION.
# [t=108.73] Patient 35 ARRIVED at exam queue.
# [t=108.73] Patient 34 STARTS service at testing (servers busy=1).
# [t=108.73] Patient 35 STARTS service at exam (servers busy=3).
# [t=111.05] Patient 35 FINISHES service at exam. Duration=2.32
# Patient 35 going to PAYMENT.
# [t=111.05] Patient 35 ARRIVED at payment queue.
# [t=111.05] Patient 35 STARTS service at payment (servers busy=1).
# [t=111.21] Patient 36 FINISHES service at exam. Duration=2.83
# Patient 36 going to PAYMENT.
# [t=111.21] Patient 36 ARRIVED at payment queue.
# [t=111.58] Patient 35 FINISHES service at payment. Duration=0.54
# === Patient 35 LEAVES system at t=111.58 ===
#
# [t=111.58] Patient 36 STARTS service at payment (servers busy=1).
# [t=111.66] Patient 34 FINISHES service at testing. Duration=2.93
# Patient 34 entering EXAMINATION.
# [t=111.66] Patient 34 ARRIVED at exam queue.
# [t=111.66] Patient 34 STARTS service at exam (servers busy=2).
# [t=111.73] Patient 34 FINISHES service at exam. Duration=0.07
# Patient 34 going to PAYMENT.
# [t=111.73] Patient 34 ARRIVED at payment queue.
# [t=111.92] Patient 36 FINISHES service at payment. Duration=0.34
# === Patient 36 LEAVES system at t=111.92 ===
#
# [t=111.92] Patient 34 STARTS service at payment (servers busy=1).
# [t=112.30] Patient 32 FINISHES service at exam. Duration=8.49
# Patient 32 going to PAYMENT.
# [t=112.30] Patient 32 ARRIVED at payment queue.
# [t=114.12] Patient 34 FINISHES service at payment. Duration=2.21
# === Patient 34 LEAVES system at t=114.12 ===
#
# [t=114.12] Patient 32 STARTS service at payment (servers busy=1).
# [t=114.20] Patient 32 FINISHES service at payment. Duration=0.07
# === Patient 32 LEAVES system at t=114.20 ===
#
#
# === Patient 37 ENTERS system at t=118.60 ===
# Patient 37 going to RECEPTION.
# [t=118.60] Patient 37 ARRIVED at reception queue.
# [t=118.60] Patient 37 STARTS service at reception (servers busy=1).
# [t=118.90] Patient 37 FINISHES service at reception. Duration=0.31
# Patient 37 SKIPS testing and goes to EXAM.
# Patient 37 entering EXAMINATION.
# [t=118.90] Patient 37 ARRIVED at exam queue.
# [t=118.90] Patient 37 STARTS service at exam (servers busy=1).
# [t=126.31] Patient 37 FINISHES service at exam. Duration=7.40
# Patient 37 going to PAYMENT.
# [t=126.31] Patient 37 ARRIVED at payment queue.
# [t=126.31] Patient 37 STARTS service at payment (servers busy=1).
# [t=129.63] Patient 37 FINISHES service at payment. Duration=3.32
# === Patient 37 LEAVES system at t=129.63 ===
#
#
# === Patient 38 ENTERS system at t=139.54 ===
# Patient 38 going to RECEPTION.
# [t=139.54] Patient 38 ARRIVED at reception queue.
# [t=139.54] Patient 38 STARTS service at reception (servers busy=1).
#
# === Patient 39 ENTERS system at t=141.62 ===
# Patient 39 going to RECEPTION.
# [t=141.62] Patient 39 ARRIVED at reception queue.
# [t=141.62] Patient 39 STARTS service at reception (servers busy=2).
# [t=144.14] Patient 38 FINISHES service at reception. Duration=4.60
# Patient 38 routed to TESTING.
# [t=144.14] Patient 38 ARRIVED at testing queue.
# [t=144.14] Patient 38 STARTS service at testing (servers busy=1).
# [t=144.59] Patient 39 FINISHES service at reception. Duration=2.98
# Patient 39 SKIPS testing and goes to EXAM.
# Patient 39 entering EXAMINATION.
# [t=144.59] Patient 39 ARRIVED at exam queue.
# [t=144.59] Patient 39 STARTS service at exam (servers busy=1).
# [t=145.88] Patient 39 FINISHES service at exam. Duration=1.29
# Patient 39 going to PAYMENT.
# [t=145.88] Patient 39 ARRIVED at payment queue.
# [t=145.88] Patient 39 STARTS service at payment (servers busy=1).
# [t=146.31] Patient 38 FINISHES service at testing. Duration=2.17
# Patient 38 entering EXAMINATION.
# [t=146.31] Patient 38 ARRIVED at exam queue.
# [t=146.31] Patient 38 STARTS service at exam (servers busy=1).
# [t=146.52] Patient 38 FINISHES service at exam. Duration=0.22
# Patient 38 going to PAYMENT.
# [t=146.52] Patient 38 ARRIVED at payment queue.
# [t=147.82] Patient 39 FINISHES service at payment. Duration=1.94
# === Patient 39 LEAVES system at t=147.82 ===
#
# [t=147.82] Patient 38 STARTS service at payment (servers busy=1).
# [t=148.13] Patient 38 FINISHES service at payment. Duration=0.31
# === Patient 38 LEAVES system at t=148.13 ===
#
#
# === Patient 40 ENTERS system at t=148.90 ===
# Patient 40 going to RECEPTION.
# [t=148.90] Patient 40 ARRIVED at reception queue.
# [t=148.90] Patient 40 STARTS service at reception (servers busy=1).
# [t=150.01] Patient 40 FINISHES service at reception. Duration=1.11
# Patient 40 SKIPS testing and goes to EXAM.
# Patient 40 entering EXAMINATION.
# [t=150.01] Patient 40 ARRIVED at exam queue.
# [t=150.01] Patient 40 STARTS service at exam (servers busy=1).
#
# === Patient 41 ENTERS system at t=150.69 ===
# Patient 41 going to RECEPTION.
# [t=150.69] Patient 41 ARRIVED at reception queue.
# [t=150.69] Patient 41 STARTS service at reception (servers busy=1).
# [t=150.79] Patient 41 FINISHES service at reception. Duration=0.10
# Patient 41 SKIPS testing and goes to EXAM.
# Patient 41 entering EXAMINATION.
# [t=150.79] Patient 41 ARRIVED at exam queue.
# [t=150.79] Patient 41 STARTS service at exam (servers busy=2).
#
# === Patient 42 ENTERS system at t=151.29 ===
# Patient 42 going to RECEPTION.
# [t=151.29] Patient 42 ARRIVED at reception queue.
# [t=151.29] Patient 42 STARTS service at reception (servers busy=1).
# [t=152.30] Patient 40 FINISHES service at exam. Duration=2.29
# Patient 40 going to PAYMENT.
# [t=152.30] Patient 40 ARRIVED at payment queue.
# [t=152.30] Patient 40 STARTS service at payment (servers busy=1).
# [t=154.95] Patient 42 FINISHES service at reception. Duration=3.66
# Patient 42 SKIPS testing and goes to EXAM.
# Patient 42 entering EXAMINATION.
# [t=154.95] Patient 42 ARRIVED at exam queue.
# [t=154.95] Patient 42 STARTS service at exam (servers busy=2).
# [t=155.60] Patient 41 FINISHES service at exam. Duration=4.81
# Patient 41 requires RE-EXAM. Returning to EXAM queue.
# Patient 41 entering EXAMINATION.
# [t=155.60] Patient 41 ARRIVED at exam queue.
# [t=155.60] Patient 41 STARTS service at exam (servers busy=2).
# [t=155.64] Patient 40 FINISHES service at payment. Duration=3.35
# === Patient 40 LEAVES system at t=155.64 ===
#
# [t=156.06] Patient 42 FINISHES service at exam. Duration=1.11
# Patient 42 going to PAYMENT.
# [t=156.06] Patient 42 ARRIVED at payment queue.
# [t=156.06] Patient 42 STARTS service at payment (servers busy=1).
# [t=156.61] Patient 42 FINISHES service at payment. Duration=0.55
# === Patient 42 LEAVES system at t=156.61 ===
#
# [t=157.55] Patient 41 FINISHES service at exam. Duration=1.95
# Patient 41 going to PAYMENT.
# [t=157.55] Patient 41 ARRIVED at payment queue.
# [t=157.55] Patient 41 STARTS service at payment (servers busy=1).
#
# === Patient 43 ENTERS system at t=160.01 ===
# Patient 43 going to RECEPTION.
# [t=160.01] Patient 43 ARRIVED at reception queue.
# [t=160.01] Patient 43 STARTS service at reception (servers busy=1).
#
# === Patient 44 ENTERS system at t=160.25 ===
# Patient 44 going to RECEPTION.
# [t=160.25] Patient 44 ARRIVED at reception queue.
# [t=160.25] Patient 44 STARTS service at reception (servers busy=2).
#
# === Patient 45 ENTERS system at t=161.99 ===
# Patient 45 going to RECEPTION.
# [t=161.99] Patient 45 ARRIVED at reception queue.
# [t=162.26] Patient 41 FINISHES service at payment. Duration=4.71
# === Patient 41 LEAVES system at t=162.26 ===
#
#
# === Patient 46 ENTERS system at t=162.38 ===
# Patient 46 going to RECEPTION.
# [t=162.38] Patient 46 ARRIVED at reception queue.
# [t=163.38] Patient 44 FINISHES service at reception. Duration=3.14
# Patient 44 SKIPS testing and goes to EXAM.
# Patient 44 entering EXAMINATION.
# [t=163.38] Patient 44 ARRIVED at exam queue.
# [t=163.38] Patient 45 STARTS service at reception (servers busy=2).
# [t=163.38] Patient 44 STARTS service at exam (servers busy=1).
# [t=164.53] Patient 45 FINISHES service at reception. Duration=1.15
# Patient 45 SKIPS testing and goes to EXAM.
# Patient 45 entering EXAMINATION.
# [t=164.53] Patient 45 ARRIVED at exam queue.
# [t=164.53] Patient 46 STARTS service at reception (servers busy=2).
# [t=164.53] Patient 45 STARTS service at exam (servers busy=2).
# [t=164.85] Patient 44 FINISHES service at exam. Duration=1.47
# Patient 44 going to PAYMENT.
# [t=164.85] Patient 44 ARRIVED at payment queue.
# [t=164.85] Patient 44 STARTS service at payment (servers busy=1).
# [t=164.92] Patient 44 FINISHES service at payment. Duration=0.06
# === Patient 44 LEAVES system at t=164.92 ===
#
# [t=164.96] Patient 46 FINISHES service at reception. Duration=0.43
# Patient 46 SKIPS testing and goes to EXAM.
# Patient 46 entering EXAMINATION.
# [t=164.96] Patient 46 ARRIVED at exam queue.
# [t=164.96] Patient 46 STARTS service at exam (servers busy=2).
#
# === Patient 47 ENTERS system at t=165.19 ===
# Patient 47 going to RECEPTION.
# [t=165.19] Patient 47 ARRIVED at reception queue.
# [t=165.19] Patient 47 STARTS service at reception (servers busy=2).
# [t=165.21] Patient 47 FINISHES service at reception. Duration=0.02
# Patient 47 SKIPS testing and goes to EXAM.
# Patient 47 entering EXAMINATION.
# [t=165.21] Patient 47 ARRIVED at exam queue.
# [t=165.21] Patient 47 STARTS service at exam (servers busy=3).
# [t=165.22] Patient 46 FINISHES service at exam. Duration=0.25
# Patient 46 requires RE-EXAM. Returning to EXAM queue.
# Patient 46 entering EXAMINATION.
# [t=165.22] Patient 46 ARRIVED at exam queue.
# [t=165.22] Patient 46 STARTS service at exam (servers busy=3).
# [t=165.32] Patient 45 FINISHES service at exam. Duration=0.79
# Patient 45 going to PAYMENT.
# [t=165.32] Patient 45 ARRIVED at payment queue.
# [t=165.32] Patient 45 STARTS service at payment (servers busy=1).
# [t=165.62] Patient 43 FINISHES service at reception. Duration=5.61
# Patient 43 SKIPS testing and goes to EXAM.
# Patient 43 entering EXAMINATION.
# [t=165.62] Patient 43 ARRIVED at exam queue.
# [t=165.62] Patient 43 STARTS service at exam (servers busy=3).
# [t=166.77] Patient 43 FINISHES service at exam. Duration=1.15
# Patient 43 going to PAYMENT.
# [t=166.77] Patient 43 ARRIVED at payment queue.
# [t=167.85] Patient 47 FINISHES service at exam. Duration=2.64
# Patient 47 going to PAYMENT.
# [t=167.85] Patient 47 ARRIVED at payment queue.
# [t=168.84] Patient 45 FINISHES service at payment. Duration=3.52
# === Patient 45 LEAVES system at t=168.84 ===
#
# [t=168.84] Patient 43 STARTS service at payment (servers busy=1).
# [t=170.70] Patient 43 FINISHES service at payment. Duration=1.85
# === Patient 43 LEAVES system at t=170.70 ===
#
# [t=170.70] Patient 47 STARTS service at payment (servers busy=1).
# [t=173.57] Patient 47 FINISHES service at payment. Duration=2.87
# === Patient 47 LEAVES system at t=173.57 ===
#
#
# === Patient 48 ENTERS system at t=173.92 ===
# Patient 48 going to RECEPTION.
# [t=173.92] Patient 48 ARRIVED at reception queue.
# [t=173.92] Patient 48 STARTS service at reception (servers busy=1).
# [t=173.97] Patient 48 FINISHES service at reception. Duration=0.05
# Patient 48 SKIPS testing and goes to EXAM.
# Patient 48 entering EXAMINATION.
# [t=173.97] Patient 48 ARRIVED at exam queue.
# [t=173.97] Patient 48 STARTS service at exam (servers busy=2).
# [t=174.53] Patient 48 FINISHES service at exam. Duration=0.55
# Patient 48 going to PAYMENT.
# [t=174.53] Patient 48 ARRIVED at payment queue.
# [t=174.53] Patient 48 STARTS service at payment (servers busy=1).
# [t=174.68] Patient 46 FINISHES service at exam. Duration=9.46
# Patient 46 going to PAYMENT.
# [t=174.68] Patient 46 ARRIVED at payment queue.
#
# === Patient 49 ENTERS system at t=174.72 ===
# Patient 49 going to RECEPTION.
# [t=174.72] Patient 49 ARRIVED at reception queue.
# [t=174.72] Patient 49 STARTS service at reception (servers busy=1).
# [t=174.95] Patient 48 FINISHES service at payment. Duration=0.42
# === Patient 48 LEAVES system at t=174.95 ===
#
# [t=174.95] Patient 46 STARTS service at payment (servers busy=1).
# [t=175.77] Patient 46 FINISHES service at payment. Duration=0.82
# === Patient 46 LEAVES system at t=175.77 ===
#
# [t=176.36] Patient 49 FINISHES service at reception. Duration=1.64
# Patient 49 SKIPS testing and goes to EXAM.
# Patient 49 entering EXAMINATION.
# [t=176.36] Patient 49 ARRIVED at exam queue.
# [t=176.36] Patient 49 STARTS service at exam (servers busy=1).
#
# === Patient 50 ENTERS system at t=176.62 ===
# Patient 50 going to RECEPTION.
# [t=176.62] Patient 50 ARRIVED at reception queue.
# [t=176.62] Patient 50 STARTS service at reception (servers busy=1).
#
# === Patient 51 ENTERS system at t=176.76 ===
# Patient 51 going to RECEPTION.
# [t=176.76] Patient 51 ARRIVED at reception queue.
# [t=176.76] Patient 51 STARTS service at reception (servers busy=2).
# [t=176.92] Patient 50 FINISHES service at reception. Duration=0.30
# Patient 50 routed to TESTING.
# [t=176.92] Patient 50 ARRIVED at testing queue.
# [t=176.92] Patient 50 STARTS service at testing (servers busy=1).
# [t=178.46] Patient 50 FINISHES service at testing. Duration=1.54
# Patient 50 entering EXAMINATION.
# [t=178.46] Patient 50 ARRIVED at exam queue.
# [t=178.46] Patient 50 STARTS service at exam (servers busy=2).
# [t=178.65] Patient 49 FINISHES service at exam. Duration=2.29
# Patient 49 going to PAYMENT.
# [t=178.65] Patient 49 ARRIVED at payment queue.
# [t=178.65] Patient 49 STARTS service at payment (servers busy=1).
# [t=178.68] Patient 49 FINISHES service at payment. Duration=0.03
# === Patient 49 LEAVES system at t=178.68 ===
#
#
# === Patient 52 ENTERS system at t=181.14 ===
# Patient 52 going to RECEPTION.
# [t=181.14] Patient 52 ARRIVED at reception queue.
# [t=181.14] Patient 52 STARTS service at reception (servers busy=2).
# [t=181.64] Patient 51 FINISHES service at reception. Duration=4.88
# Patient 51 routed to TESTING.
# [t=181.64] Patient 51 ARRIVED at testing queue.
# [t=181.64] Patient 51 STARTS service at testing (servers busy=1).
# [t=181.82] Patient 52 FINISHES service at reception. Duration=0.68
# Patient 52 routed to TESTING.
# [t=181.82] Patient 52 ARRIVED at testing queue.
#
# === Patient 53 ENTERS system at t=183.59 ===
# Patient 53 going to RECEPTION.
# [t=183.59] Patient 53 ARRIVED at reception queue.
# [t=183.59] Patient 53 STARTS service at reception (servers busy=1).
# [t=185.06] Patient 50 FINISHES service at exam. Duration=6.61
# Patient 50 going to PAYMENT.
# [t=185.06] Patient 50 ARRIVED at payment queue.
# [t=185.06] Patient 50 STARTS service at payment (servers busy=1).
# [t=185.72] Patient 50 FINISHES service at payment. Duration=0.65
# === Patient 50 LEAVES system at t=185.72 ===
#
# [t=186.39] Patient 53 FINISHES service at reception. Duration=2.80
# Patient 53 routed to TESTING.
# [t=186.39] Patient 53 ARRIVED at testing queue.
# [t=188.53] Patient 51 FINISHES service at testing. Duration=6.90
# Patient 51 entering EXAMINATION.
# [t=188.53] Patient 51 ARRIVED at exam queue.
# [t=188.53] Patient 52 STARTS service at testing (servers busy=1).
# [t=188.53] Patient 51 STARTS service at exam (servers busy=1).
#
# === Patient 54 ENTERS system at t=189.50 ===
# Patient 54 going to RECEPTION.
# [t=189.50] Patient 54 ARRIVED at reception queue.
# [t=189.50] Patient 54 STARTS service at reception (servers busy=1).
# [t=189.76] Patient 54 FINISHES service at reception. Duration=0.27
# Patient 54 SKIPS testing and goes to EXAM.
# Patient 54 entering EXAMINATION.
# [t=189.76] Patient 54 ARRIVED at exam queue.
# [t=189.76] Patient 54 STARTS service at exam (servers busy=2).
#
# === Patient 55 ENTERS system at t=190.16 ===
# Patient 55 going to RECEPTION.
# [t=190.16] Patient 55 ARRIVED at reception queue.
# [t=190.16] Patient 55 STARTS service at reception (servers busy=1).
#
# === Patient 56 ENTERS system at t=190.17 ===
# Patient 56 going to RECEPTION.
# [t=190.17] Patient 56 ARRIVED at reception queue.
# [t=190.17] Patient 56 STARTS service at reception (servers busy=2).
# [t=190.24] Patient 56 FINISHES service at reception. Duration=0.07
# Patient 56 routed to TESTING.
# [t=190.24] Patient 56 ARRIVED at testing queue.
#
# === Patient 57 ENTERS system at t=190.47 ===
# Patient 57 going to RECEPTION.
# [t=190.47] Patient 57 ARRIVED at reception queue.
# [t=190.47] Patient 57 STARTS service at reception (servers busy=2).
# [t=191.30] Patient 52 FINISHES service at testing. Duration=2.76
# Patient 52 entering EXAMINATION.
# [t=191.30] Patient 52 ARRIVED at exam queue.
# [t=191.30] Patient 53 STARTS service at testing (servers busy=1).
# [t=191.30] Patient 52 STARTS service at exam (servers busy=3).
# [t=191.50] Patient 52 FINISHES service at exam. Duration=0.20
# Patient 52 going to PAYMENT.
# [t=191.50] Patient 52 ARRIVED at payment queue.
# [t=191.50] Patient 52 STARTS service at payment (servers busy=1).
#
# === Patient 58 ENTERS system at t=192.51 ===
# Patient 58 going to RECEPTION.
# [t=192.51] Patient 58 ARRIVED at reception queue.
# [t=192.53] Patient 52 FINISHES service at payment. Duration=1.03
# === Patient 52 LEAVES system at t=192.53 ===
#
#
# === Patient 59 ENTERS system at t=192.83 ===
# Patient 59 going to RECEPTION.
# [t=192.83] Patient 59 ARRIVED at reception queue.
# [t=193.27] Patient 55 FINISHES service at reception. Duration=3.11
# Patient 55 SKIPS testing and goes to EXAM.
# Patient 55 entering EXAMINATION.
# [t=193.27] Patient 55 ARRIVED at exam queue.
# [t=193.27] Patient 58 STARTS service at reception (servers busy=2).
# [t=193.27] Patient 55 STARTS service at exam (servers busy=3).
# [t=194.00] Patient 53 FINISHES service at testing. Duration=2.71
# Patient 53 entering EXAMINATION.
# [t=194.00] Patient 53 ARRIVED at exam queue.
# [t=194.00] Patient 56 STARTS service at testing (servers busy=1).
# [t=196.00] Patient 57 FINISHES service at reception. Duration=5.53
# Patient 57 routed to TESTING.
# [t=196.00] Patient 57 ARRIVED at testing queue.
# [t=196.00] Patient 59 STARTS service at reception (servers busy=2).
# [t=196.12] Patient 54 FINISHES service at exam. Duration=6.35
# Patient 54 going to PAYMENT.
# [t=196.12] Patient 54 ARRIVED at payment queue.
# [t=196.12] Patient 53 STARTS service at exam (servers busy=3).
# [t=196.12] Patient 54 STARTS service at payment (servers busy=1).
# [t=196.13] Patient 54 FINISHES service at payment. Duration=0.02
# === Patient 54 LEAVES system at t=196.13 ===
#
# [t=196.43] Patient 53 FINISHES service at exam. Duration=0.31
# Patient 53 going to PAYMENT.
# [t=196.43] Patient 53 ARRIVED at payment queue.
# [t=196.43] Patient 53 STARTS service at payment (servers busy=1).
#
# === Patient 60 ENTERS system at t=196.51 ===
# Patient 60 going to RECEPTION.
# [t=196.51] Patient 60 ARRIVED at reception queue.
# [t=197.13] Patient 59 FINISHES service at reception. Duration=1.13
# Patient 59 SKIPS testing and goes to EXAM.
# Patient 59 entering EXAMINATION.
# [t=197.13] Patient 59 ARRIVED at exam queue.
# [t=197.13] Patient 60 STARTS service at reception (servers busy=2).
# [t=197.13] Patient 59 STARTS service at exam (servers busy=3).
# [t=197.25] Patient 60 FINISHES service at reception. Duration=0.12
# Patient 60 SKIPS testing and goes to EXAM.
# Patient 60 entering EXAMINATION.
# [t=197.25] Patient 60 ARRIVED at exam queue.
# [t=197.28] Patient 53 FINISHES service at payment. Duration=0.85
# === Patient 53 LEAVES system at t=197.28 ===
#
# [t=197.35] Patient 59 FINISHES service at exam. Duration=0.22
# Patient 59 going to PAYMENT.
# [t=197.35] Patient 59 ARRIVED at payment queue.
# [t=197.35] Patient 60 STARTS service at exam (servers busy=3).
# [t=197.35] Patient 59 STARTS service at payment (servers busy=1).
# [t=197.80] Patient 60 FINISHES service at exam. Duration=0.45
# Patient 60 going to PAYMENT.
# [t=197.80] Patient 60 ARRIVED at payment queue.
# [t=198.25] Patient 56 FINISHES service at testing. Duration=4.24
# Patient 56 entering EXAMINATION.
# [t=198.25] Patient 56 ARRIVED at exam queue.
# [t=198.25] Patient 57 STARTS service at testing (servers busy=1).
# [t=198.25] Patient 56 STARTS service at exam (servers busy=3).
# [t=198.98] Patient 55 FINISHES service at exam. Duration=5.71
# Patient 55 going to PAYMENT.
# [t=198.98] Patient 55 ARRIVED at payment queue.
# [t=199.20] Patient 51 FINISHES service at exam. Duration=10.67
# Patient 51 going to PAYMENT.
# [t=199.20] Patient 51 ARRIVED at payment queue.
# [t=199.52] Patient 58 FINISHES service at reception. Duration=6.25
# Patient 58 routed to TESTING.
# [t=199.52] Patient 58 ARRIVED at testing queue.
# [t=199.98] Patient 59 FINISHES service at payment. Duration=2.62
# === Patient 59 LEAVES system at t=199.98 ===
#
# [t=199.98] Patient 60 STARTS service at payment (servers busy=1).
# Simulation finished (no metrics attached). Node servers and rates:
#  - reception: servers=2, mu=0.5
#  - testing: servers=1, mu=0.4
#  - exam: servers=3, mu=0.3
#  - payment: servers=1, mu=0.6

# %% [markdown]
# # 4. Present results

# %%
# Out:
# Streaming output truncated to the last 5000 lines.
# [t=23826.81] Patient 10054 FINISHES service at exam. Duration=0.20
# [t=23826.81] Patient 10054 ARRIVED at payment queue.
# [t=23828.14] Patient 10055 ARRIVED at reception queue.
# [t=23828.14] Patient 10055 STARTS service at reception (servers busy=2).
# [t=23828.19] Patient 10049 FINISHES service at payment. Duration=1.57
# [t=23828.19] Patient 10052 STARTS service at payment (servers busy=1).
# [t=23828.31] Patient 10052 FINISHES service at payment. Duration=0.12
# [t=23828.31] Patient 10050 STARTS service at payment (servers busy=1).
# [t=23828.31] Patient 10050 FINISHES service at payment. Duration=0.00
# [t=23828.31] Patient 10051 STARTS service at payment (servers busy=1).
# [t=23828.52] Patient 10053 FINISHES service at reception. Duration=3.39
# [t=23828.52] Patient 10053 ARRIVED at exam queue.
# [t=23828.52] Patient 10053 STARTS service at exam (servers busy=1).
# [t=23829.09] Patient 10056 ARRIVED at reception queue.
# [t=23829.09] Patient 10056 STARTS service at reception (servers busy=2).
# [t=23829.92] Patient 10051 FINISHES service at payment. Duration=1.60
# [t=23829.92] Patient 10054 STARTS service at payment (servers busy=1).
# [t=23830.09] Patient 10057 ARRIVED at reception queue.
# [t=23830.77] Patient 10054 FINISHES service at payment. Duration=0.85
# [t=23832.79] Patient 10055 FINISHES service at reception. Duration=4.65
# [t=23832.79] Patient 10057 STARTS service at reception (servers busy=2).
# [t=23832.79] Patient 10055 ARRIVED at testing queue.
# [t=23832.79] Patient 10055 STARTS service at testing (servers busy=1).
# [t=23832.90] Patient 10057 FINISHES service at reception. Duration=0.12
# [t=23832.90] Patient 10057 ARRIVED at exam queue.
# [t=23832.90] Patient 10057 STARTS service at exam (servers busy=2).
# [t=23833.05] Patient 10057 FINISHES service at exam. Duration=0.15
# [t=23833.05] Patient 10057 ARRIVED at payment queue.
# [t=23833.05] Patient 10057 STARTS service at payment (servers busy=1).
# [t=23833.88] Patient 10055 FINISHES service at testing. Duration=1.09
# [t=23833.88] Patient 10055 ARRIVED at exam queue.
# [t=23833.88] Patient 10055 STARTS service at exam (servers busy=2).
# [t=23834.44] Patient 10053 FINISHES service at exam. Duration=5.93
# [t=23834.44] Patient 10053 ARRIVED at payment queue.
# [t=23834.51] Patient 10056 FINISHES service at reception. Duration=5.41
# [t=23834.51] Patient 10056 ARRIVED at exam queue.
# [t=23834.51] Patient 10056 STARTS service at exam (servers busy=2).
# [t=23834.95] Patient 10058 ARRIVED at reception queue.
# [t=23834.95] Patient 10058 STARTS service at reception (servers busy=1).
# [t=23835.16] Patient 10058 FINISHES service at reception. Duration=0.21
# [t=23835.16] Patient 10058 ARRIVED at exam queue.
# [t=23835.16] Patient 10058 STARTS service at exam (servers busy=3).
# [t=23835.45] Patient 10059 ARRIVED at reception queue.
# [t=23835.45] Patient 10059 STARTS service at reception (servers busy=1).
# [t=23835.58] Patient 10058 FINISHES service at exam. Duration=0.43
# [t=23835.58] Patient 10058 ARRIVED at exam queue.
# [t=23835.58] Patient 10058 STARTS service at exam (servers busy=3).
# [t=23835.61] Patient 10058 FINISHES service at exam. Duration=0.03
# [t=23835.61] Patient 10058 ARRIVED at payment queue.
# [t=23835.97] Patient 10060 ARRIVED at reception queue.
# [t=23835.97] Patient 10060 STARTS service at reception (servers busy=2).
# [t=23836.23] Patient 10061 ARRIVED at reception queue.
# [t=23836.40] Patient 10060 FINISHES service at reception. Duration=0.43
# [t=23836.40] Patient 10061 STARTS service at reception (servers busy=2).
# [t=23836.40] Patient 10060 ARRIVED at testing queue.
# [t=23836.40] Patient 10060 STARTS service at testing (servers busy=1).
# [t=23836.54] Patient 10059 FINISHES service at reception. Duration=1.09
# [t=23836.54] Patient 10059 ARRIVED at exam queue.
# [t=23836.54] Patient 10059 STARTS service at exam (servers busy=3).
# [t=23836.55] Patient 10056 FINISHES service at exam. Duration=2.05
# [t=23836.55] Patient 10056 ARRIVED at payment queue.
# [t=23836.61] Patient 10059 FINISHES service at exam. Duration=0.07
# [t=23836.61] Patient 10059 ARRIVED at payment queue.
# [t=23838.65] Patient 10061 FINISHES service at reception. Duration=2.24
# [t=23838.65] Patient 10061 ARRIVED at exam queue.
# [t=23838.65] Patient 10061 STARTS service at exam (servers busy=2).
# [t=23839.04] Patient 10055 FINISHES service at exam. Duration=5.16
# [t=23839.04] Patient 10055 ARRIVED at payment queue.
# [t=23839.56] Patient 10062 ARRIVED at reception queue.
# [t=23839.56] Patient 10062 STARTS service at reception (servers busy=1).
# [t=23840.27] Patient 10060 FINISHES service at testing. Duration=3.86
# [t=23840.27] Patient 10060 ARRIVED at exam queue.
# [t=23840.27] Patient 10060 STARTS service at exam (servers busy=2).
# [t=23841.02] Patient 10061 FINISHES service at exam. Duration=2.37
# [t=23841.02] Patient 10061 ARRIVED at exam queue.
# [t=23841.02] Patient 10061 STARTS service at exam (servers busy=2).
# [t=23841.63] Patient 10057 FINISHES service at payment. Duration=8.58
# [t=23841.63] Patient 10053 STARTS service at payment (servers busy=1).
# [t=23841.88] Patient 10053 FINISHES service at payment. Duration=0.25
# [t=23841.88] Patient 10058 STARTS service at payment (servers busy=1).
# [t=23843.19] Patient 10058 FINISHES service at payment. Duration=1.31
# [t=23843.19] Patient 10056 STARTS service at payment (servers busy=1).
# [t=23843.23] Patient 10063 ARRIVED at reception queue.
# [t=23843.23] Patient 10063 STARTS service at reception (servers busy=2).
# [t=23843.84] Patient 10063 FINISHES service at reception. Duration=0.61
# [t=23843.84] Patient 10063 ARRIVED at exam queue.
# [t=23843.84] Patient 10063 STARTS service at exam (servers busy=3).
# [t=23845.48] Patient 10063 FINISHES service at exam. Duration=1.64
# [t=23845.48] Patient 10063 ARRIVED at exam queue.
# [t=23845.48] Patient 10063 STARTS service at exam (servers busy=3).
# [t=23845.64] Patient 10060 FINISHES service at exam. Duration=5.37
# [t=23845.64] Patient 10060 ARRIVED at payment queue.
# [t=23845.65] Patient 10062 FINISHES service at reception. Duration=6.10
# [t=23845.65] Patient 10062 ARRIVED at testing queue.
# [t=23845.65] Patient 10062 STARTS service at testing (servers busy=1).
# [t=23845.97] Patient 10056 FINISHES service at payment. Duration=2.78
# [t=23845.97] Patient 10059 STARTS service at payment (servers busy=1).
# [t=23846.07] Patient 10059 FINISHES service at payment. Duration=0.11
# [t=23846.07] Patient 10055 STARTS service at payment (servers busy=1).
# [t=23846.97] Patient 10063 FINISHES service at exam. Duration=1.49
# [t=23846.97] Patient 10063 ARRIVED at payment queue.
# [t=23847.19] Patient 10064 ARRIVED at reception queue.
# [t=23847.19] Patient 10064 STARTS service at reception (servers busy=1).
# [t=23847.38] Patient 10055 FINISHES service at payment. Duration=1.30
# [t=23847.38] Patient 10060 STARTS service at payment (servers busy=1).
# [t=23848.37] Patient 10062 FINISHES service at testing. Duration=2.72
# [t=23848.37] Patient 10062 ARRIVED at exam queue.
# [t=23848.37] Patient 10062 STARTS service at exam (servers busy=2).
# [t=23848.75] Patient 10065 ARRIVED at reception queue.
# [t=23848.75] Patient 10065 STARTS service at reception (servers busy=2).
# [t=23849.28] Patient 10065 FINISHES service at reception. Duration=0.53
# [t=23849.28] Patient 10065 ARRIVED at exam queue.
# [t=23849.28] Patient 10065 STARTS service at exam (servers busy=3).
# [t=23849.62] Patient 10064 FINISHES service at reception. Duration=2.44
# [t=23849.62] Patient 10064 ARRIVED at testing queue.
# [t=23849.62] Patient 10064 STARTS service at testing (servers busy=1).
# [t=23849.72] Patient 10065 FINISHES service at exam. Duration=0.45
# [t=23849.72] Patient 10065 ARRIVED at exam queue.
# [t=23849.72] Patient 10065 STARTS service at exam (servers busy=3).
# [t=23849.78] Patient 10062 FINISHES service at exam. Duration=1.41
# [t=23849.78] Patient 10062 ARRIVED at payment queue.
# [t=23850.54] Patient 10066 ARRIVED at reception queue.
# [t=23850.54] Patient 10066 STARTS service at reception (servers busy=1).
# [t=23851.03] Patient 10060 FINISHES service at payment. Duration=3.65
# [t=23851.03] Patient 10063 STARTS service at payment (servers busy=1).
# [t=23851.18] Patient 10067 ARRIVED at reception queue.
# [t=23851.18] Patient 10067 STARTS service at reception (servers busy=2).
# [t=23851.65] Patient 10068 ARRIVED at reception queue.
# [t=23851.66] Patient 10061 FINISHES service at exam. Duration=10.65
# [t=23851.66] Patient 10061 ARRIVED at payment queue.
# [t=23851.97] Patient 10064 FINISHES service at testing. Duration=2.34
# [t=23851.97] Patient 10064 ARRIVED at exam queue.
# [t=23851.97] Patient 10064 STARTS service at exam (servers busy=2).
# [t=23852.11] Patient 10066 FINISHES service at reception. Duration=1.57
# [t=23852.11] Patient 10068 STARTS service at reception (servers busy=2).
# [t=23852.11] Patient 10066 ARRIVED at exam queue.
# [t=23852.11] Patient 10066 STARTS service at exam (servers busy=3).
# [t=23852.49] Patient 10063 FINISHES service at payment. Duration=1.46
# [t=23852.49] Patient 10062 STARTS service at payment (servers busy=1).
# [t=23852.64] Patient 10067 FINISHES service at reception. Duration=1.46
# [t=23852.64] Patient 10067 ARRIVED at exam queue.
# [t=23853.48] Patient 10064 FINISHES service at exam. Duration=1.52
# [t=23853.48] Patient 10067 STARTS service at exam (servers busy=3).
# [t=23853.48] Patient 10064 ARRIVED at payment queue.
# [t=23853.55] Patient 10068 FINISHES service at reception. Duration=1.44
# [t=23853.55] Patient 10068 ARRIVED at exam queue.
# [t=23853.94] Patient 10069 ARRIVED at reception queue.
# [t=23853.94] Patient 10069 STARTS service at reception (servers busy=1).
# [t=23854.24] Patient 10067 FINISHES service at exam. Duration=0.75
# [t=23854.24] Patient 10068 STARTS service at exam (servers busy=3).
# [t=23854.24] Patient 10067 ARRIVED at exam queue.
# [t=23854.91] Patient 10069 FINISHES service at reception. Duration=0.97
# [t=23854.91] Patient 10069 ARRIVED at exam queue.
# [t=23854.91] Patient 10066 FINISHES service at exam. Duration=2.80
# [t=23854.91] Patient 10067 STARTS service at exam (servers busy=3).
# [t=23854.91] Patient 10066 ARRIVED at payment queue.
# [t=23856.11] Patient 10062 FINISHES service at payment. Duration=3.63
# [t=23856.11] Patient 10061 STARTS service at payment (servers busy=1).
# [t=23856.20] Patient 10070 ARRIVED at reception queue.
# [t=23856.20] Patient 10070 STARTS service at reception (servers busy=1).
# [t=23856.21] Patient 10067 FINISHES service at exam. Duration=1.30
# [t=23856.21] Patient 10069 STARTS service at exam (servers busy=3).
# [t=23856.21] Patient 10067 ARRIVED at payment queue.
# [t=23856.63] Patient 10069 FINISHES service at exam. Duration=0.42
# [t=23856.63] Patient 10069 ARRIVED at payment queue.
# [t=23856.69] Patient 10068 FINISHES service at exam. Duration=2.45
# [t=23856.69] Patient 10068 ARRIVED at payment queue.
# [t=23857.06] Patient 10070 FINISHES service at reception. Duration=0.86
# [t=23857.06] Patient 10070 ARRIVED at exam queue.
# [t=23857.06] Patient 10070 STARTS service at exam (servers busy=2).
# [t=23857.45] Patient 10071 ARRIVED at reception queue.
# [t=23857.45] Patient 10071 STARTS service at reception (servers busy=1).
# [t=23857.52] Patient 10065 FINISHES service at exam. Duration=7.80
# [t=23857.52] Patient 10065 ARRIVED at payment queue.
# [t=23857.91] Patient 10061 FINISHES service at payment. Duration=1.79
# [t=23857.91] Patient 10064 STARTS service at payment (servers busy=1).
# [t=23858.27] Patient 10070 FINISHES service at exam. Duration=1.21
# [t=23858.27] Patient 10070 ARRIVED at payment queue.
# [t=23858.43] Patient 10064 FINISHES service at payment. Duration=0.52
# [t=23858.43] Patient 10066 STARTS service at payment (servers busy=1).
# [t=23858.99] Patient 10072 ARRIVED at reception queue.
# [t=23858.99] Patient 10072 STARTS service at reception (servers busy=2).
# [t=23859.05] Patient 10073 ARRIVED at reception queue.
# [t=23859.10] Patient 10072 FINISHES service at reception. Duration=0.11
# [t=23859.10] Patient 10073 STARTS service at reception (servers busy=2).
# [t=23859.10] Patient 10072 ARRIVED at exam queue.
# [t=23859.10] Patient 10072 STARTS service at exam (servers busy=1).
# [t=23861.20] Patient 10073 FINISHES service at reception. Duration=2.10
# [t=23861.20] Patient 10073 ARRIVED at testing queue.
# [t=23861.20] Patient 10073 STARTS service at testing (servers busy=1).
# [t=23861.89] Patient 10066 FINISHES service at payment. Duration=3.46
# [t=23861.89] Patient 10067 STARTS service at payment (servers busy=1).
# [t=23862.67] Patient 10067 FINISHES service at payment. Duration=0.78
# [t=23862.67] Patient 10069 STARTS service at payment (servers busy=1).
# [t=23863.28] Patient 10069 FINISHES service at payment. Duration=0.60
# [t=23863.28] Patient 10068 STARTS service at payment (servers busy=1).
# [t=23864.46] Patient 10072 FINISHES service at exam. Duration=5.37
# [t=23864.46] Patient 10072 ARRIVED at payment queue.
# [t=23864.61] Patient 10073 FINISHES service at testing. Duration=3.42
# [t=23864.61] Patient 10073 ARRIVED at exam queue.
# [t=23864.61] Patient 10073 STARTS service at exam (servers busy=1).
# [t=23865.30] Patient 10074 ARRIVED at reception queue.
# [t=23865.30] Patient 10074 STARTS service at reception (servers busy=2).
# [t=23865.42] Patient 10075 ARRIVED at reception queue.
# [t=23865.53] Patient 10068 FINISHES service at payment. Duration=2.25
# [t=23865.53] Patient 10065 STARTS service at payment (servers busy=1).
# [t=23866.35] Patient 10076 ARRIVED at reception queue.
# [t=23866.77] Patient 10071 FINISHES service at reception. Duration=9.32
# [t=23866.77] Patient 10075 STARTS service at reception (servers busy=2).
# [t=23866.77] Patient 10071 ARRIVED at exam queue.
# [t=23866.77] Patient 10071 STARTS service at exam (servers busy=2).
# [t=23866.83] Patient 10074 FINISHES service at reception. Duration=1.53
# [t=23866.83] Patient 10076 STARTS service at reception (servers busy=2).
# [t=23866.83] Patient 10074 ARRIVED at exam queue.
# [t=23866.83] Patient 10074 STARTS service at exam (servers busy=3).
# [t=23866.85] Patient 10071 FINISHES service at exam. Duration=0.07
# [t=23866.85] Patient 10071 ARRIVED at payment queue.
# [t=23867.28] Patient 10077 ARRIVED at reception queue.
# [t=23868.07] Patient 10075 FINISHES service at reception. Duration=1.29
# [t=23868.07] Patient 10077 STARTS service at reception (servers busy=2).
# [t=23868.07] Patient 10075 ARRIVED at exam queue.
# [t=23868.07] Patient 10075 STARTS service at exam (servers busy=3).
# [t=23868.35] Patient 10076 FINISHES service at reception. Duration=1.52
# [t=23868.35] Patient 10076 ARRIVED at testing queue.
# [t=23868.35] Patient 10076 STARTS service at testing (servers busy=1).
# [t=23868.40] Patient 10074 FINISHES service at exam. Duration=1.57
# [t=23868.40] Patient 10074 ARRIVED at payment queue.
# [t=23868.57] Patient 10065 FINISHES service at payment. Duration=3.04
# [t=23868.57] Patient 10070 STARTS service at payment (servers busy=1).
# [t=23868.63] Patient 10077 FINISHES service at reception. Duration=0.56
# [t=23868.63] Patient 10077 ARRIVED at exam queue.
# [t=23868.63] Patient 10077 STARTS service at exam (servers busy=3).
# [t=23868.75] Patient 10077 FINISHES service at exam. Duration=0.12
# [t=23868.75] Patient 10077 ARRIVED at payment queue.
# [t=23869.52] Patient 10070 FINISHES service at payment. Duration=0.96
# [t=23869.52] Patient 10072 STARTS service at payment (servers busy=1).
# [t=23869.61] Patient 10076 FINISHES service at testing. Duration=1.26
# [t=23869.61] Patient 10076 ARRIVED at exam queue.
# [t=23869.61] Patient 10076 STARTS service at exam (servers busy=3).
# [t=23870.17] Patient 10073 FINISHES service at exam. Duration=5.56
# [t=23870.17] Patient 10073 ARRIVED at exam queue.
# [t=23870.17] Patient 10073 STARTS service at exam (servers busy=3).
# [t=23873.86] Patient 10073 FINISHES service at exam. Duration=3.70
# [t=23873.86] Patient 10073 ARRIVED at payment queue.
# [t=23876.01] Patient 10078 ARRIVED at reception queue.
# [t=23876.01] Patient 10078 STARTS service at reception (servers busy=1).
# [t=23876.27] Patient 10075 FINISHES service at exam. Duration=8.20
# [t=23876.27] Patient 10075 ARRIVED at payment queue.
# [t=23878.29] Patient 10079 ARRIVED at reception queue.
# [t=23878.29] Patient 10079 STARTS service at reception (servers busy=2).
# [t=23878.48] Patient 10076 FINISHES service at exam. Duration=8.86
# [t=23878.48] Patient 10076 ARRIVED at payment queue.
# [t=23878.52] Patient 10080 ARRIVED at reception queue.
# [t=23879.80] Patient 10072 FINISHES service at payment. Duration=10.27
# [t=23879.80] Patient 10071 STARTS service at payment (servers busy=1).
# [t=23880.11] Patient 10078 FINISHES service at reception. Duration=4.10
# [t=23880.11] Patient 10080 STARTS service at reception (servers busy=2).
# [t=23880.11] Patient 10078 ARRIVED at exam queue.
# [t=23880.11] Patient 10078 STARTS service at exam (servers busy=1).
# [t=23880.32] Patient 10078 FINISHES service at exam. Duration=0.21
# [t=23880.32] Patient 10078 ARRIVED at payment queue.
# [t=23880.90] Patient 10080 FINISHES service at reception. Duration=0.79
# [t=23880.90] Patient 10080 ARRIVED at exam queue.
# [t=23880.90] Patient 10080 STARTS service at exam (servers busy=1).
# [t=23881.36] Patient 10071 FINISHES service at payment. Duration=1.57
# [t=23881.36] Patient 10074 STARTS service at payment (servers busy=1).
# [t=23881.70] Patient 10074 FINISHES service at payment. Duration=0.33
# [t=23881.70] Patient 10077 STARTS service at payment (servers busy=1).
# [t=23881.80] Patient 10080 FINISHES service at exam. Duration=0.90
# [t=23881.80] Patient 10080 ARRIVED at payment queue.
# [t=23881.94] Patient 10077 FINISHES service at payment. Duration=0.25
# [t=23881.94] Patient 10073 STARTS service at payment (servers busy=1).
# [t=23883.07] Patient 10073 FINISHES service at payment. Duration=1.12
# [t=23883.07] Patient 10075 STARTS service at payment (servers busy=1).
# [t=23884.37] Patient 10079 FINISHES service at reception. Duration=6.09
# [t=23884.37] Patient 10079 ARRIVED at exam queue.
# [t=23884.37] Patient 10079 STARTS service at exam (servers busy=1).
# [t=23885.45] Patient 10081 ARRIVED at reception queue.
# [t=23885.45] Patient 10081 STARTS service at reception (servers busy=1).
# [t=23885.76] Patient 10079 FINISHES service at exam. Duration=1.39
# [t=23885.76] Patient 10079 ARRIVED at exam queue.
# [t=23885.76] Patient 10079 STARTS service at exam (servers busy=1).
# [t=23886.16] Patient 10082 ARRIVED at reception queue.
# [t=23886.16] Patient 10082 STARTS service at reception (servers busy=2).
# [t=23887.33] Patient 10075 FINISHES service at payment. Duration=4.26
# [t=23887.33] Patient 10076 STARTS service at payment (servers busy=1).
# [t=23887.45] Patient 10082 FINISHES service at reception. Duration=1.29
# [t=23887.45] Patient 10082 ARRIVED at testing queue.
# [t=23887.45] Patient 10082 STARTS service at testing (servers busy=1).
# [t=23887.54] Patient 10076 FINISHES service at payment. Duration=0.21
# [t=23887.54] Patient 10078 STARTS service at payment (servers busy=1).
# [t=23887.92] Patient 10082 FINISHES service at testing. Duration=0.47
# [t=23887.92] Patient 10082 ARRIVED at exam queue.
# [t=23887.92] Patient 10082 STARTS service at exam (servers busy=2).
# [t=23888.43] Patient 10082 FINISHES service at exam. Duration=0.51
# [t=23888.43] Patient 10082 ARRIVED at payment queue.
# [t=23890.40] Patient 10079 FINISHES service at exam. Duration=4.64
# [t=23890.40] Patient 10079 ARRIVED at payment queue.
# [t=23890.65] Patient 10078 FINISHES service at payment. Duration=3.10
# [t=23890.65] Patient 10080 STARTS service at payment (servers busy=1).
# [t=23891.48] Patient 10080 FINISHES service at payment. Duration=0.84
# [t=23891.48] Patient 10082 STARTS service at payment (servers busy=1).
# [t=23891.53] Patient 10081 FINISHES service at reception. Duration=6.08
# [t=23891.53] Patient 10081 ARRIVED at exam queue.
# [t=23891.53] Patient 10081 STARTS service at exam (servers busy=1).
# [t=23895.21] Patient 10081 FINISHES service at exam. Duration=3.68
# [t=23895.21] Patient 10081 ARRIVED at payment queue.
# [t=23896.63] Patient 10082 FINISHES service at payment. Duration=5.15
# [t=23896.63] Patient 10079 STARTS service at payment (servers busy=1).
# [t=23897.46] Patient 10083 ARRIVED at reception queue.
# [t=23897.46] Patient 10083 STARTS service at reception (servers busy=1).
# [t=23898.24] Patient 10079 FINISHES service at payment. Duration=1.61
# [t=23898.24] Patient 10081 STARTS service at payment (servers busy=1).
# [t=23899.64] Patient 10081 FINISHES service at payment. Duration=1.40
# [t=23902.00] Patient 10084 ARRIVED at reception queue.
# [t=23902.00] Patient 10084 STARTS service at reception (servers busy=2).
# [t=23902.56] Patient 10084 FINISHES service at reception. Duration=0.56
# [t=23902.56] Patient 10084 ARRIVED at exam queue.
# [t=23902.56] Patient 10084 STARTS service at exam (servers busy=1).
# [t=23904.57] Patient 10085 ARRIVED at reception queue.
# [t=23904.57] Patient 10085 STARTS service at reception (servers busy=2).
# [t=23904.61] Patient 10086 ARRIVED at reception queue.
# [t=23906.45] Patient 10087 ARRIVED at reception queue.
# [t=23907.06] Patient 10085 FINISHES service at reception. Duration=2.49
# [t=23907.06] Patient 10086 STARTS service at reception (servers busy=2).
# [t=23907.06] Patient 10085 ARRIVED at exam queue.
# [t=23907.06] Patient 10085 STARTS service at exam (servers busy=2).
# [t=23907.12] Patient 10088 ARRIVED at reception queue.
# [t=23907.48] Patient 10089 ARRIVED at reception queue.
# [t=23907.75] Patient 10086 FINISHES service at reception. Duration=0.69
# [t=23907.75] Patient 10087 STARTS service at reception (servers busy=2).
# [t=23907.75] Patient 10086 ARRIVED at testing queue.
# [t=23907.75] Patient 10086 STARTS service at testing (servers busy=1).
# [t=23908.02] Patient 10085 FINISHES service at exam. Duration=0.96
# [t=23908.02] Patient 10085 ARRIVED at payment queue.
# [t=23908.02] Patient 10085 STARTS service at payment (servers busy=1).
# [t=23908.16] Patient 10086 FINISHES service at testing. Duration=0.41
# [t=23908.16] Patient 10086 ARRIVED at exam queue.
# [t=23908.16] Patient 10086 STARTS service at exam (servers busy=2).
# [t=23910.04] Patient 10083 FINISHES service at reception. Duration=12.58
# [t=23910.04] Patient 10088 STARTS service at reception (servers busy=2).
# [t=23910.04] Patient 10083 ARRIVED at exam queue.
# [t=23910.04] Patient 10083 STARTS service at exam (servers busy=3).
# [t=23910.48] Patient 10084 FINISHES service at exam. Duration=7.92
# [t=23910.48] Patient 10084 ARRIVED at payment queue.
# [t=23911.09] Patient 10090 ARRIVED at reception queue.
# [t=23911.88] Patient 10087 FINISHES service at reception. Duration=4.14
# [t=23911.88] Patient 10089 STARTS service at reception (servers busy=2).
# [t=23911.88] Patient 10087 ARRIVED at testing queue.
# [t=23911.88] Patient 10087 STARTS service at testing (servers busy=1).
# [t=23912.68] Patient 10086 FINISHES service at exam. Duration=4.52
# [t=23912.68] Patient 10086 ARRIVED at payment queue.
# [t=23913.07] Patient 10089 FINISHES service at reception. Duration=1.19
# [t=23913.07] Patient 10090 STARTS service at reception (servers busy=2).
# [t=23913.07] Patient 10089 ARRIVED at exam queue.
# [t=23913.07] Patient 10089 STARTS service at exam (servers busy=2).
# [t=23913.10] Patient 10087 FINISHES service at testing. Duration=1.22
# [t=23913.10] Patient 10087 ARRIVED at exam queue.
# [t=23913.10] Patient 10087 STARTS service at exam (servers busy=3).
# [t=23913.37] Patient 10089 FINISHES service at exam. Duration=0.29
# [t=23913.37] Patient 10089 ARRIVED at payment queue.
# [t=23913.63] Patient 10087 FINISHES service at exam. Duration=0.53
# [t=23913.63] Patient 10087 ARRIVED at exam queue.
# [t=23913.63] Patient 10087 STARTS service at exam (servers busy=2).
# [t=23914.32] Patient 10087 FINISHES service at exam. Duration=0.68
# [t=23914.32] Patient 10087 ARRIVED at payment queue.
# [t=23914.47] Patient 10090 FINISHES service at reception. Duration=1.39
# [t=23914.47] Patient 10090 ARRIVED at exam queue.
# [t=23914.47] Patient 10090 STARTS service at exam (servers busy=2).
# [t=23915.75] Patient 10083 FINISHES service at exam. Duration=5.71
# [t=23915.75] Patient 10083 ARRIVED at payment queue.
# [t=23915.75] Patient 10085 FINISHES service at payment. Duration=7.74
# [t=23915.75] Patient 10084 STARTS service at payment (servers busy=1).
# [t=23915.92] Patient 10091 ARRIVED at reception queue.
# [t=23915.92] Patient 10091 STARTS service at reception (servers busy=2).
# [t=23915.97] Patient 10091 FINISHES service at reception. Duration=0.04
# [t=23915.97] Patient 10091 ARRIVED at exam queue.
# [t=23915.97] Patient 10091 STARTS service at exam (servers busy=2).
# [t=23917.65] Patient 10084 FINISHES service at payment. Duration=1.89
# [t=23917.65] Patient 10086 STARTS service at payment (servers busy=1).
# [t=23917.65] Patient 10088 FINISHES service at reception. Duration=7.61
# [t=23917.65] Patient 10088 ARRIVED at testing queue.
# [t=23917.65] Patient 10088 STARTS service at testing (servers busy=1).
# [t=23917.80] Patient 10090 FINISHES service at exam. Duration=3.34
# [t=23917.80] Patient 10090 ARRIVED at payment queue.
# [t=23918.50] Patient 10088 FINISHES service at testing. Duration=0.84
# [t=23918.50] Patient 10088 ARRIVED at exam queue.
# [t=23918.50] Patient 10088 STARTS service at exam (servers busy=2).
# [t=23919.43] Patient 10088 FINISHES service at exam. Duration=0.94
# [t=23919.43] Patient 10088 ARRIVED at payment queue.
# [t=23920.17] Patient 10086 FINISHES service at payment. Duration=2.52
# [t=23920.17] Patient 10089 STARTS service at payment (servers busy=1).
# [t=23920.71] Patient 10092 ARRIVED at reception queue.
# [t=23920.71] Patient 10092 STARTS service at reception (servers busy=1).
# [t=23920.99] Patient 10089 FINISHES service at payment. Duration=0.82
# [t=23920.99] Patient 10087 STARTS service at payment (servers busy=1).
# [t=23921.13] Patient 10093 ARRIVED at reception queue.
# [t=23921.13] Patient 10093 STARTS service at reception (servers busy=2).
# [t=23921.36] Patient 10094 ARRIVED at reception queue.
# [t=23921.37] Patient 10087 FINISHES service at payment. Duration=0.38
# [t=23921.37] Patient 10083 STARTS service at payment (servers busy=1).
# [t=23922.36] Patient 10095 ARRIVED at reception queue.
# [t=23922.49] Patient 10092 FINISHES service at reception. Duration=1.78
# [t=23922.49] Patient 10094 STARTS service at reception (servers busy=2).
# [t=23922.49] Patient 10092 ARRIVED at exam queue.
# [t=23922.49] Patient 10092 STARTS service at exam (servers busy=2).
# [t=23922.92] Patient 10093 FINISHES service at reception. Duration=1.79
# [t=23922.92] Patient 10095 STARTS service at reception (servers busy=2).
# [t=23922.92] Patient 10093 ARRIVED at exam queue.
# [t=23922.92] Patient 10093 STARTS service at exam (servers busy=3).
# [t=23923.03] Patient 10083 FINISHES service at payment. Duration=1.66
# [t=23923.03] Patient 10090 STARTS service at payment (servers busy=1).
# [t=23923.09] Patient 10095 FINISHES service at reception. Duration=0.17
# [t=23923.09] Patient 10095 ARRIVED at exam queue.
# [t=23923.32] Patient 10090 FINISHES service at payment. Duration=0.29
# [t=23923.32] Patient 10088 STARTS service at payment (servers busy=1).
# [t=23923.93] Patient 10092 FINISHES service at exam. Duration=1.44
# [t=23923.93] Patient 10095 STARTS service at exam (servers busy=3).
# [t=23923.93] Patient 10092 ARRIVED at payment queue.
# [t=23924.98] Patient 10096 ARRIVED at reception queue.
# [t=23924.98] Patient 10096 STARTS service at reception (servers busy=2).
# [t=23925.22] Patient 10088 FINISHES service at payment. Duration=1.91
# [t=23925.22] Patient 10092 STARTS service at payment (servers busy=1).
# [t=23926.00] Patient 10097 ARRIVED at reception queue.
# [t=23926.68] Patient 10095 FINISHES service at exam. Duration=2.74
# [t=23926.68] Patient 10095 ARRIVED at payment queue.
# [t=23927.08] Patient 10094 FINISHES service at reception. Duration=4.59
# [t=23927.08] Patient 10097 STARTS service at reception (servers busy=2).
# [t=23927.08] Patient 10094 ARRIVED at testing queue.
# [t=23927.08] Patient 10094 STARTS service at testing (servers busy=1).
# [t=23927.15] Patient 10098 ARRIVED at reception queue.
# [t=23927.59] Patient 10097 FINISHES service at reception. Duration=0.51
# [t=23927.59] Patient 10098 STARTS service at reception (servers busy=2).
# [t=23927.59] Patient 10097 ARRIVED at exam queue.
# [t=23927.59] Patient 10097 STARTS service at exam (servers busy=3).
# [t=23927.70] Patient 10092 FINISHES service at payment. Duration=2.47
# [t=23927.70] Patient 10095 STARTS service at payment (servers busy=1).
# [t=23927.74] Patient 10099 ARRIVED at reception queue.
# [t=23929.14] Patient 10095 FINISHES service at payment. Duration=1.44
# [t=23929.82] Patient 10091 FINISHES service at exam. Duration=13.85
# [t=23929.82] Patient 10091 ARRIVED at payment queue.
# [t=23929.82] Patient 10091 STARTS service at payment (servers busy=1).
# [t=23929.94] Patient 10094 FINISHES service at testing. Duration=2.86
# [t=23929.94] Patient 10094 ARRIVED at exam queue.
# [t=23929.94] Patient 10094 STARTS service at exam (servers busy=3).
# [t=23929.95] Patient 10093 FINISHES service at exam. Duration=7.03
# [t=23929.95] Patient 10093 ARRIVED at payment queue.
# [t=23930.44] Patient 10091 FINISHES service at payment. Duration=0.62
# [t=23930.44] Patient 10093 STARTS service at payment (servers busy=1).
# [t=23930.87] Patient 10093 FINISHES service at payment. Duration=0.43
# [t=23930.99] Patient 10098 FINISHES service at reception. Duration=3.40
# [t=23930.99] Patient 10099 STARTS service at reception (servers busy=2).
# [t=23930.99] Patient 10098 ARRIVED at testing queue.
# [t=23930.99] Patient 10098 STARTS service at testing (servers busy=1).
# [t=23931.01] Patient 10099 FINISHES service at reception. Duration=0.02
# [t=23931.01] Patient 10099 ARRIVED at testing queue.
# [t=23931.47] Patient 10096 FINISHES service at reception. Duration=6.49
# [t=23931.47] Patient 10096 ARRIVED at exam queue.
# [t=23931.47] Patient 10096 STARTS service at exam (servers busy=3).
# [t=23931.60] Patient 10094 FINISHES service at exam. Duration=1.66
# [t=23931.60] Patient 10094 ARRIVED at payment queue.
# [t=23931.60] Patient 10094 STARTS service at payment (servers busy=1).
# [t=23932.83] Patient 10096 FINISHES service at exam. Duration=1.36
# [t=23932.83] Patient 10096 ARRIVED at payment queue.
# [t=23932.87] Patient 10100 ARRIVED at reception queue.
# [t=23932.87] Patient 10100 STARTS service at reception (servers busy=1).
# [t=23933.21] Patient 10101 ARRIVED at reception queue.
# [t=23933.21] Patient 10101 STARTS service at reception (servers busy=2).
# [t=23933.81] Patient 10098 FINISHES service at testing. Duration=2.82
# [t=23933.81] Patient 10099 STARTS service at testing (servers busy=1).
# [t=23933.81] Patient 10098 ARRIVED at exam queue.
# [t=23933.81] Patient 10098 STARTS service at exam (servers busy=2).
# [t=23933.84] Patient 10099 FINISHES service at testing. Duration=0.03
# [t=23933.84] Patient 10099 ARRIVED at exam queue.
# [t=23933.84] Patient 10099 STARTS service at exam (servers busy=3).
# [t=23934.27] Patient 10102 ARRIVED at reception queue.
# [t=23934.44] Patient 10098 FINISHES service at exam. Duration=0.64
# [t=23934.44] Patient 10098 ARRIVED at payment queue.
# [t=23935.05] Patient 10100 FINISHES service at reception. Duration=2.18
# [t=23935.05] Patient 10102 STARTS service at reception (servers busy=2).
# [t=23935.05] Patient 10100 ARRIVED at testing queue.
# [t=23935.05] Patient 10100 STARTS service at testing (servers busy=1).
# [t=23935.95] Patient 10103 ARRIVED at reception queue.
# [t=23936.27] Patient 10100 FINISHES service at testing. Duration=1.23
# [t=23936.27] Patient 10100 ARRIVED at exam queue.
# [t=23936.27] Patient 10100 STARTS service at exam (servers busy=3).
# [t=23936.34] Patient 10099 FINISHES service at exam. Duration=2.50
# [t=23936.34] Patient 10099 ARRIVED at exam queue.
# [t=23936.34] Patient 10099 STARTS service at exam (servers busy=3).
# [t=23936.57] Patient 10102 FINISHES service at reception. Duration=1.52
# [t=23936.57] Patient 10103 STARTS service at reception (servers busy=2).
# [t=23936.57] Patient 10102 ARRIVED at exam queue.
# [t=23936.68] Patient 10101 FINISHES service at reception. Duration=3.47
# [t=23936.68] Patient 10101 ARRIVED at exam queue.
# [t=23936.92] Patient 10104 ARRIVED at reception queue.
# [t=23936.92] Patient 10104 STARTS service at reception (servers busy=2).
# [t=23937.62] Patient 10094 FINISHES service at payment. Duration=6.02
# [t=23937.62] Patient 10096 STARTS service at payment (servers busy=1).
# [t=23938.41] Patient 10097 FINISHES service at exam. Duration=10.83
# [t=23938.41] Patient 10102 STARTS service at exam (servers busy=3).
# [t=23938.41] Patient 10097 ARRIVED at payment queue.
# [t=23938.65] Patient 10102 FINISHES service at exam. Duration=0.23
# [t=23938.65] Patient 10101 STARTS service at exam (servers busy=3).
# [t=23938.65] Patient 10102 ARRIVED at payment queue.
# [t=23938.82] Patient 10103 FINISHES service at reception. Duration=2.25
# [t=23938.82] Patient 10103 ARRIVED at exam queue.
# [t=23939.05] Patient 10096 FINISHES service at payment. Duration=1.43
# [t=23939.05] Patient 10098 STARTS service at payment (servers busy=1).
# [t=23939.40] Patient 10101 FINISHES service at exam. Duration=0.76
# [t=23939.40] Patient 10103 STARTS service at exam (servers busy=3).
# [t=23939.40] Patient 10101 ARRIVED at payment queue.
# [t=23939.85] Patient 10098 FINISHES service at payment. Duration=0.80
# [t=23939.85] Patient 10097 STARTS service at payment (servers busy=1).
# [t=23940.69] Patient 10097 FINISHES service at payment. Duration=0.84
# [t=23940.69] Patient 10102 STARTS service at payment (servers busy=1).
# [t=23940.95] Patient 10102 FINISHES service at payment. Duration=0.26
# [t=23940.95] Patient 10101 STARTS service at payment (servers busy=1).
# [t=23942.55] Patient 10104 FINISHES service at reception. Duration=5.64
# [t=23942.55] Patient 10104 ARRIVED at exam queue.
# [t=23942.81] Patient 10101 FINISHES service at payment. Duration=1.86
# [t=23943.04] Patient 10100 FINISHES service at exam. Duration=6.77
# [t=23943.04] Patient 10104 STARTS service at exam (servers busy=3).
# [t=23943.04] Patient 10100 ARRIVED at payment queue.
# [t=23943.04] Patient 10100 STARTS service at payment (servers busy=1).
# [t=23943.21] Patient 10105 ARRIVED at reception queue.
# [t=23943.21] Patient 10105 STARTS service at reception (servers busy=1).
# [t=23943.24] Patient 10099 FINISHES service at exam. Duration=6.90
# [t=23943.24] Patient 10099 ARRIVED at exam queue.
# [t=23943.24] Patient 10099 STARTS service at exam (servers busy=3).
# [t=23943.68] Patient 10106 ARRIVED at reception queue.
# [t=23943.68] Patient 10106 STARTS service at reception (servers busy=2).
# [t=23943.93] Patient 10100 FINISHES service at payment. Duration=0.89
# [t=23943.93] Patient 10105 FINISHES service at reception. Duration=0.72
# [t=23943.93] Patient 10105 ARRIVED at exam queue.
# [t=23944.29] Patient 10104 FINISHES service at exam. Duration=1.24
# [t=23944.29] Patient 10105 STARTS service at exam (servers busy=3).
# [t=23944.29] Patient 10104 ARRIVED at payment queue.
# [t=23944.29] Patient 10104 STARTS service at payment (servers busy=1).
# [t=23944.76] Patient 10103 FINISHES service at exam. Duration=5.35
# [t=23944.76] Patient 10103 ARRIVED at payment queue.
# [t=23945.13] Patient 10099 FINISHES service at exam. Duration=1.90
# [t=23945.13] Patient 10099 ARRIVED at payment queue.
# [t=23945.56] Patient 10107 ARRIVED at reception queue.
# [t=23945.56] Patient 10107 STARTS service at reception (servers busy=2).
# [t=23946.21] Patient 10106 FINISHES service at reception. Duration=2.52
# [t=23946.21] Patient 10106 ARRIVED at exam queue.
# [t=23946.21] Patient 10106 STARTS service at exam (servers busy=2).
# [t=23946.39] Patient 10106 FINISHES service at exam. Duration=0.19
# [t=23946.39] Patient 10106 ARRIVED at payment queue.
# [t=23946.48] Patient 10105 FINISHES service at exam. Duration=2.19
# [t=23946.48] Patient 10105 ARRIVED at payment queue.
# [t=23946.74] Patient 10108 ARRIVED at reception queue.
# [t=23946.74] Patient 10108 STARTS service at reception (servers busy=2).
# [t=23947.37] Patient 10107 FINISHES service at reception. Duration=1.81
# [t=23947.37] Patient 10107 ARRIVED at testing queue.
# [t=23947.37] Patient 10107 STARTS service at testing (servers busy=1).
# [t=23947.59] Patient 10109 ARRIVED at reception queue.
# [t=23947.59] Patient 10109 STARTS service at reception (servers busy=2).
# [t=23947.63] Patient 10110 ARRIVED at reception queue.
# [t=23948.53] Patient 10104 FINISHES service at payment. Duration=4.24
# [t=23948.53] Patient 10103 STARTS service at payment (servers busy=1).
# [t=23949.89] Patient 10111 ARRIVED at reception queue.
# [t=23950.16] Patient 10112 ARRIVED at reception queue.
# [t=23950.42] Patient 10109 FINISHES service at reception. Duration=2.83
# [t=23950.42] Patient 10110 STARTS service at reception (servers busy=2).
# [t=23950.42] Patient 10109 ARRIVED at testing queue.
# [t=23952.10] Patient 10103 FINISHES service at payment. Duration=3.57
# [t=23952.10] Patient 10099 STARTS service at payment (servers busy=1).
# [t=23952.27] Patient 10110 FINISHES service at reception. Duration=1.86
# [t=23952.27] Patient 10111 STARTS service at reception (servers busy=2).
# [t=23952.27] Patient 10110 ARRIVED at exam queue.
# [t=23952.27] Patient 10110 STARTS service at exam (servers busy=1).
# [t=23953.19] Patient 10107 FINISHES service at testing. Duration=5.82
# [t=23953.19] Patient 10109 STARTS service at testing (servers busy=1).
# [t=23953.19] Patient 10107 ARRIVED at exam queue.
# [t=23953.19] Patient 10107 STARTS service at exam (servers busy=2).
# [t=23955.14] Patient 10110 FINISHES service at exam. Duration=2.86
# [t=23955.14] Patient 10110 ARRIVED at payment queue.
# [t=23955.33] Patient 10111 FINISHES service at reception. Duration=3.05
# [t=23955.33] Patient 10112 STARTS service at reception (servers busy=2).
# [t=23955.33] Patient 10111 ARRIVED at testing queue.
# [t=23955.60] Patient 10099 FINISHES service at payment. Duration=3.50
# [t=23955.60] Patient 10106 STARTS service at payment (servers busy=1).
# [t=23956.22] Patient 10113 ARRIVED at reception queue.
# [t=23956.29] Patient 10114 ARRIVED at reception queue.
# [t=23956.89] Patient 10109 FINISHES service at testing. Duration=3.70
# [t=23956.89] Patient 10111 STARTS service at testing (servers busy=1).
# [t=23956.89] Patient 10109 ARRIVED at exam queue.
# [t=23956.89] Patient 10109 STARTS service at exam (servers busy=2).
# [t=23957.28] Patient 10106 FINISHES service at payment. Duration=1.68
# [t=23957.28] Patient 10105 STARTS service at payment (servers busy=1).
# [t=23957.55] Patient 10115 ARRIVED at reception queue.
# [t=23957.70] Patient 10105 FINISHES service at payment. Duration=0.42
# [t=23957.70] Patient 10110 STARTS service at payment (servers busy=1).
# [t=23957.71] Patient 10107 FINISHES service at exam. Duration=4.53
# [t=23957.71] Patient 10107 ARRIVED at payment queue.
# [t=23957.83] Patient 10112 FINISHES service at reception. Duration=2.51
# [t=23957.83] Patient 10113 STARTS service at reception (servers busy=2).
# [t=23957.83] Patient 10112 ARRIVED at exam queue.
# [t=23957.83] Patient 10112 STARTS service at exam (servers busy=2).
# [t=23958.18] Patient 10108 FINISHES service at reception. Duration=11.44
# [t=23958.18] Patient 10114 STARTS service at reception (servers busy=2).
# [t=23958.18] Patient 10108 ARRIVED at exam queue.
# [t=23958.18] Patient 10108 STARTS service at exam (servers busy=3).
# [t=23958.60] Patient 10113 FINISHES service at reception. Duration=0.76
# [t=23958.60] Patient 10115 STARTS service at reception (servers busy=2).
# [t=23958.60] Patient 10113 ARRIVED at exam queue.
# [t=23958.60] Patient 10116 ARRIVED at reception queue.
# [t=23958.63] Patient 10111 FINISHES service at testing. Duration=1.75
# [t=23958.63] Patient 10111 ARRIVED at exam queue.
# [t=23959.72] Patient 10117 ARRIVED at reception queue.
# [t=23960.12] Patient 10114 FINISHES service at reception. Duration=1.94
# [t=23960.12] Patient 10116 STARTS service at reception (servers busy=2).
# [t=23960.12] Patient 10114 ARRIVED at exam queue.
# [t=23960.62] Patient 10110 FINISHES service at payment. Duration=2.92
# [t=23960.62] Patient 10107 STARTS service at payment (servers busy=1).
# [t=23961.03] Patient 10115 FINISHES service at reception. Duration=2.43
# [t=23961.03] Patient 10117 STARTS service at reception (servers busy=2).
# [t=23961.03] Patient 10115 ARRIVED at testing queue.
# [t=23961.03] Patient 10115 STARTS service at testing (servers busy=1).
# [t=23961.05] Patient 10117 FINISHES service at reception. Duration=0.02
# [t=23961.05] Patient 10117 ARRIVED at exam queue.
# [t=23961.47] Patient 10107 FINISHES service at payment. Duration=0.84
# [t=23961.81] Patient 10115 FINISHES service at testing. Duration=0.78
# [t=23961.81] Patient 10115 ARRIVED at exam queue.
# [t=23962.22] Patient 10118 ARRIVED at reception queue.
# [t=23962.22] Patient 10118 STARTS service at reception (servers busy=2).
# [t=23962.26] Patient 10118 FINISHES service at reception. Duration=0.04
# [t=23962.26] Patient 10118 ARRIVED at exam queue.
# [t=23962.89] Patient 10108 FINISHES service at exam. Duration=4.71
# [t=23962.89] Patient 10113 STARTS service at exam (servers busy=3).
# [t=23962.89] Patient 10108 ARRIVED at payment queue.
# [t=23962.89] Patient 10108 STARTS service at payment (servers busy=1).
# [t=23963.06] Patient 10108 FINISHES service at payment. Duration=0.17
# [t=23963.27] Patient 10113 FINISHES service at exam. Duration=0.38
# [t=23963.27] Patient 10111 STARTS service at exam (servers busy=3).
# [t=23963.27] Patient 10113 ARRIVED at payment queue.
# [t=23963.27] Patient 10113 STARTS service at payment (servers busy=1).
# [t=23963.28] Patient 10113 FINISHES service at payment. Duration=0.01
# [t=23964.60] Patient 10119 ARRIVED at reception queue.
# [t=23964.60] Patient 10119 STARTS service at reception (servers busy=2).
# [t=23964.94] Patient 10112 FINISHES service at exam. Duration=7.10
# [t=23964.94] Patient 10114 STARTS service at exam (servers busy=3).
# [t=23964.94] Patient 10112 ARRIVED at payment queue.
# [t=23964.94] Patient 10112 STARTS service at payment (servers busy=1).
# [t=23965.39] Patient 10116 FINISHES service at reception. Duration=5.27
# [t=23965.39] Patient 10116 ARRIVED at exam queue.
# [t=23965.46] Patient 10112 FINISHES service at payment. Duration=0.53
# [t=23966.04] Patient 10111 FINISHES service at exam. Duration=2.77
# [t=23966.04] Patient 10117 STARTS service at exam (servers busy=3).
# [t=23966.04] Patient 10111 ARRIVED at payment queue.
# [t=23966.04] Patient 10111 STARTS service at payment (servers busy=1).
# [t=23966.94] Patient 10120 ARRIVED at reception queue.
# [t=23966.94] Patient 10120 STARTS service at reception (servers busy=2).
# [t=23967.05] Patient 10111 FINISHES service at payment. Duration=1.01
# [t=23967.79] Patient 10119 FINISHES service at reception. Duration=3.18
# [t=23967.79] Patient 10119 ARRIVED at exam queue.
# [t=23967.81] Patient 10109 FINISHES service at exam. Duration=10.92
# [t=23967.81] Patient 10115 STARTS service at exam (servers busy=3).
# [t=23967.81] Patient 10109 ARRIVED at payment queue.
# [t=23967.81] Patient 10109 STARTS service at payment (servers busy=1).
# [t=23968.03] Patient 10117 FINISHES service at exam. Duration=1.99
# [t=23968.03] Patient 10118 STARTS service at exam (servers busy=3).
# [t=23968.03] Patient 10117 ARRIVED at payment queue.
# [t=23968.75] Patient 10115 FINISHES service at exam. Duration=0.94
# [t=23968.75] Patient 10116 STARTS service at exam (servers busy=3).
# [t=23968.75] Patient 10115 ARRIVED at payment queue.
# [t=23969.02] Patient 10116 FINISHES service at exam. Duration=0.27
# [t=23969.02] Patient 10119 STARTS service at exam (servers busy=3).
# [t=23969.02] Patient 10116 ARRIVED at payment queue.
# [t=23969.50] Patient 10114 FINISHES service at exam. Duration=4.57
# [t=23969.50] Patient 10114 ARRIVED at payment queue.
# [t=23970.00] Patient 10109 FINISHES service at payment. Duration=2.19
# [t=23970.00] Patient 10117 STARTS service at payment (servers busy=1).
# [t=23970.34] Patient 10117 FINISHES service at payment. Duration=0.34
# [t=23970.34] Patient 10115 STARTS service at payment (servers busy=1).
# [t=23970.70] Patient 10120 FINISHES service at reception. Duration=3.77
# [t=23970.70] Patient 10120 ARRIVED at exam queue.
# [t=23970.70] Patient 10120 STARTS service at exam (servers busy=3).
# [t=23970.77] Patient 10121 ARRIVED at reception queue.
# [t=23970.77] Patient 10121 STARTS service at reception (servers busy=1).
# [t=23971.24] Patient 10120 FINISHES service at exam. Duration=0.54
# [t=23971.24] Patient 10120 ARRIVED at payment queue.
# [t=23971.71] Patient 10122 ARRIVED at reception queue.
# [t=23971.71] Patient 10122 STARTS service at reception (servers busy=2).
# [t=23972.47] Patient 10122 FINISHES service at reception. Duration=0.76
# [t=23972.47] Patient 10122 ARRIVED at exam queue.
# [t=23972.47] Patient 10122 STARTS service at exam (servers busy=3).
# [t=23972.55] Patient 10121 FINISHES service at reception. Duration=1.77
# [t=23972.55] Patient 10121 ARRIVED at exam queue.
# [t=23972.98] Patient 10115 FINISHES service at payment. Duration=2.64
# [t=23972.98] Patient 10116 STARTS service at payment (servers busy=1).
# [t=23973.40] Patient 10119 FINISHES service at exam. Duration=4.38
# [t=23973.40] Patient 10121 STARTS service at exam (servers busy=3).
# [t=23973.40] Patient 10119 ARRIVED at payment queue.
# [t=23973.71] Patient 10121 FINISHES service at exam. Duration=0.31
# [t=23973.71] Patient 10121 ARRIVED at payment queue.
# [t=23973.78] Patient 10123 ARRIVED at reception queue.
# [t=23973.78] Patient 10123 STARTS service at reception (servers busy=1).
# [t=23974.72] Patient 10122 FINISHES service at exam. Duration=2.26
# [t=23974.72] Patient 10122 ARRIVED at payment queue.
# [t=23974.73] Patient 10123 FINISHES service at reception. Duration=0.95
# [t=23974.73] Patient 10123 ARRIVED at testing queue.
# [t=23974.73] Patient 10123 STARTS service at testing (servers busy=1).
# [t=23974.94] Patient 10118 FINISHES service at exam. Duration=6.91
# [t=23974.94] Patient 10118 ARRIVED at payment queue.
# [t=23975.99] Patient 10123 FINISHES service at testing. Duration=1.26
# [t=23975.99] Patient 10123 ARRIVED at exam queue.
# [t=23975.99] Patient 10123 STARTS service at exam (servers busy=1).
# [t=23976.67] Patient 10123 FINISHES service at exam. Duration=0.68
# [t=23976.67] Patient 10123 ARRIVED at payment queue.
# [t=23977.91] Patient 10124 ARRIVED at reception queue.
# [t=23977.91] Patient 10124 STARTS service at reception (servers busy=1).
# [t=23979.69] Patient 10124 FINISHES service at reception. Duration=1.78
# [t=23979.69] Patient 10124 ARRIVED at testing queue.
# [t=23979.69] Patient 10124 STARTS service at testing (servers busy=1).
# [t=23979.84] Patient 10125 ARRIVED at reception queue.
# [t=23979.84] Patient 10125 STARTS service at reception (servers busy=1).
# [t=23980.94] Patient 10116 FINISHES service at payment. Duration=7.95
# [t=23980.94] Patient 10114 STARTS service at payment (servers busy=1).
# [t=23981.47] Patient 10125 FINISHES service at reception. Duration=1.63
# [t=23981.47] Patient 10125 ARRIVED at exam queue.
# [t=23981.47] Patient 10125 STARTS service at exam (servers busy=1).
# [t=23981.61] Patient 10124 FINISHES service at testing. Duration=1.91
# [t=23981.61] Patient 10124 ARRIVED at exam queue.
# [t=23981.61] Patient 10124 STARTS service at exam (servers busy=2).
# [t=23981.86] Patient 10126 ARRIVED at reception queue.
# [t=23981.86] Patient 10126 STARTS service at reception (servers busy=1).
# [t=23982.18] Patient 10127 ARRIVED at reception queue.
# [t=23982.18] Patient 10127 STARTS service at reception (servers busy=2).
# [t=23983.06] Patient 10127 FINISHES service at reception. Duration=0.88
# [t=23983.06] Patient 10127 ARRIVED at exam queue.
# [t=23983.06] Patient 10127 STARTS service at exam (servers busy=3).
# [t=23983.55] Patient 10127 FINISHES service at exam. Duration=0.49
# [t=23983.55] Patient 10127 ARRIVED at payment queue.
# [t=23984.76] Patient 10126 FINISHES service at reception. Duration=2.90
# [t=23984.76] Patient 10126 ARRIVED at testing queue.
# [t=23984.76] Patient 10126 STARTS service at testing (servers busy=1).
# [t=23984.98] Patient 10128 ARRIVED at reception queue.
# [t=23984.98] Patient 10128 STARTS service at reception (servers busy=1).
# [t=23985.40] Patient 10129 ARRIVED at reception queue.
# [t=23985.40] Patient 10129 STARTS service at reception (servers busy=2).
# [t=23985.42] Patient 10125 FINISHES service at exam. Duration=3.95
# [t=23985.42] Patient 10125 ARRIVED at payment queue.
# [t=23985.47] Patient 10128 FINISHES service at reception. Duration=0.48
# [t=23985.47] Patient 10128 ARRIVED at testing queue.
# [t=23986.19] Patient 10114 FINISHES service at payment. Duration=5.25
# ...
# [t=24954.81] Patient 10513 STARTS service at payment (servers busy=1).
# [t=24955.08] Patient 10517 FINISHES service at exam. Duration=1.15
# [t=24955.08] Patient 10518 STARTS service at exam (servers busy=3).
# [t=24955.08] Patient 10517 ARRIVED at payment queue.
# [t=24955.91] Patient 10515 FINISHES service at exam. Duration=4.58
# [t=24955.91] Patient 10515 ARRIVED at payment queue.
# [t=24956.18] Patient 10513 FINISHES service at payment. Duration=1.36
# [t=24956.18] Patient 10517 STARTS service at payment (servers busy=1).
# [t=24956.68] Patient 10519 FINISHES service at reception. Duration=2.75
# [t=24956.68] Patient 10519 ARRIVED at exam queue.
# [t=24956.68] Patient 10519 STARTS service at exam (servers busy=3).
# [t=24957.07] Patient 10520 ARRIVED at reception queue.
# [t=24957.07] Patient 10520 STARTS service at reception (servers busy=1).
# [t=24957.07] Patient 10517 FINISHES service at payment. Duration=0.90
# [t=24957.07] Patient 10515 STARTS service at payment (servers busy=1).
# [t=24957.81] Patient 10516 FINISHES service at exam. Duration=5.38
# [t=24957.81] Patient 10516 ARRIVED at payment queue.
# [t=24958.05] Patient 10515 FINISHES service at payment. Duration=0.98
# [t=24958.05] Patient 10516 STARTS service at payment (servers busy=1).
# [t=24958.35] Patient 10521 ARRIVED at reception queue.
# [t=24958.35] Patient 10521 STARTS service at reception (servers busy=2).
# [t=24958.73] Patient 10521 FINISHES service at reception. Duration=0.38
# [t=24958.73] Patient 10521 ARRIVED at exam queue.
# [t=24958.73] Patient 10521 STARTS service at exam (servers busy=3).
# [t=24958.95] Patient 10519 FINISHES service at exam. Duration=2.27
# [t=24958.95] Patient 10519 ARRIVED at payment queue.
# [t=24959.05] Patient 10521 FINISHES service at exam. Duration=0.32
# [t=24959.05] Patient 10521 ARRIVED at payment queue.
# [t=24959.35] Patient 10522 ARRIVED at reception queue.
# [t=24959.35] Patient 10522 STARTS service at reception (servers busy=2).
# [t=24959.76] Patient 10522 FINISHES service at reception. Duration=0.40
# [t=24959.76] Patient 10522 ARRIVED at testing queue.
# [t=24959.76] Patient 10522 STARTS service at testing (servers busy=1).
# [t=24959.92] Patient 10523 ARRIVED at reception queue.
# [t=24959.92] Patient 10523 STARTS service at reception (servers busy=2).
# [t=24960.15] Patient 10523 FINISHES service at reception. Duration=0.23
# [t=24960.15] Patient 10523 ARRIVED at exam queue.
# [t=24960.15] Patient 10523 STARTS service at exam (servers busy=2).
# [t=24960.95] Patient 10522 FINISHES service at testing. Duration=1.19
# [t=24960.95] Patient 10522 ARRIVED at exam queue.
# [t=24960.95] Patient 10522 STARTS service at exam (servers busy=3).
# [t=24961.70] Patient 10523 FINISHES service at exam. Duration=1.54
# [t=24961.70] Patient 10523 ARRIVED at payment queue.
# [t=24961.77] Patient 10524 ARRIVED at reception queue.
# [t=24961.77] Patient 10524 STARTS service at reception (servers busy=2).
# [t=24962.61] Patient 10525 ARRIVED at reception queue.
# [t=24962.98] Patient 10520 FINISHES service at reception. Duration=5.91
# [t=24962.98] Patient 10525 STARTS service at reception (servers busy=2).
# [t=24962.98] Patient 10520 ARRIVED at exam queue.
# [t=24962.98] Patient 10520 STARTS service at exam (servers busy=3).
# [t=24962.99] Patient 10516 FINISHES service at payment. Duration=4.94
# [t=24962.99] Patient 10519 STARTS service at payment (servers busy=1).
# [t=24963.82] Patient 10525 FINISHES service at reception. Duration=0.83
# [t=24963.82] Patient 10525 ARRIVED at testing queue.
# [t=24963.82] Patient 10525 STARTS service at testing (servers busy=1).
# [t=24964.39] Patient 10526 ARRIVED at reception queue.
# [t=24964.39] Patient 10526 STARTS service at reception (servers busy=2).
# [t=24964.67] Patient 10525 FINISHES service at testing. Duration=0.85
# [t=24964.67] Patient 10525 ARRIVED at exam queue.
# [t=24965.34] Patient 10526 FINISHES service at reception. Duration=0.95
# [t=24965.34] Patient 10526 ARRIVED at exam queue.
# [t=24965.96] Patient 10520 FINISHES service at exam. Duration=2.97
# [t=24965.96] Patient 10525 STARTS service at exam (servers busy=3).
# [t=24965.96] Patient 10520 ARRIVED at payment queue.
# [t=24966.91] Patient 10527 ARRIVED at reception queue.
# [t=24966.91] Patient 10527 STARTS service at reception (servers busy=2).
# [t=24967.17] Patient 10519 FINISHES service at payment. Duration=4.18
# [t=24967.17] Patient 10521 STARTS service at payment (servers busy=1).
# [t=24967.22] Patient 10522 FINISHES service at exam. Duration=6.27
# [t=24967.22] Patient 10526 STARTS service at exam (servers busy=3).
# [t=24967.22] Patient 10522 ARRIVED at payment queue.
# [t=24967.77] Patient 10521 FINISHES service at payment. Duration=0.60
# [t=24967.77] Patient 10523 STARTS service at payment (servers busy=1).
# [t=24968.27] Patient 10528 ARRIVED at reception queue.
# [t=24968.42] Patient 10524 FINISHES service at reception. Duration=6.66
# [t=24968.42] Patient 10528 STARTS service at reception (servers busy=2).
# [t=24968.42] Patient 10524 ARRIVED at exam queue.
# [t=24968.52] Patient 10523 FINISHES service at payment. Duration=0.74
# [t=24968.52] Patient 10520 STARTS service at payment (servers busy=1).
# [t=24968.54] Patient 10520 FINISHES service at payment. Duration=0.02
# [t=24968.54] Patient 10522 STARTS service at payment (servers busy=1).
# [t=24968.56] Patient 10522 FINISHES service at payment. Duration=0.03
# [t=24968.76] Patient 10529 ARRIVED at reception queue.
# [t=24969.10] Patient 10530 ARRIVED at reception queue.
# [t=24969.31] Patient 10531 ARRIVED at reception queue.
# [t=24969.31] Patient 10527 FINISHES service at reception. Duration=2.40
# [t=24969.31] Patient 10529 STARTS service at reception (servers busy=2).
# [t=24969.31] Patient 10527 ARRIVED at exam queue.
# [t=24969.71] Patient 10529 FINISHES service at reception. Duration=0.40
# [t=24969.71] Patient 10530 STARTS service at reception (servers busy=2).
# [t=24969.71] Patient 10529 ARRIVED at exam queue.
# [t=24969.87] Patient 10532 ARRIVED at reception queue.
# [t=24970.23] Patient 10518 FINISHES service at exam. Duration=15.15
# [t=24970.23] Patient 10524 STARTS service at exam (servers busy=3).
# [t=24970.23] Patient 10518 ARRIVED at payment queue.
# [t=24970.23] Patient 10518 STARTS service at payment (servers busy=1).
# [t=24970.40] Patient 10518 FINISHES service at payment. Duration=0.17
# [t=24970.56] Patient 10525 FINISHES service at exam. Duration=4.61
# [t=24970.56] Patient 10527 STARTS service at exam (servers busy=3).
# [t=24970.56] Patient 10525 ARRIVED at exam queue.
# [t=24971.95] Patient 10524 FINISHES service at exam. Duration=1.72
# [t=24971.95] Patient 10529 STARTS service at exam (servers busy=3).
# [t=24971.95] Patient 10524 ARRIVED at payment queue.
# [t=24971.95] Patient 10524 STARTS service at payment (servers busy=1).
# [t=24972.58] Patient 10528 FINISHES service at reception. Duration=4.16
# [t=24972.58] Patient 10531 STARTS service at reception (servers busy=2).
# [t=24972.58] Patient 10528 ARRIVED at testing queue.
# [t=24972.58] Patient 10528 STARTS service at testing (servers busy=1).
# [t=24972.88] Patient 10526 FINISHES service at exam. Duration=5.66
# [t=24972.88] Patient 10525 STARTS service at exam (servers busy=3).
# [t=24972.88] Patient 10526 ARRIVED at payment queue.
# [t=24972.88] Patient 10528 FINISHES service at testing. Duration=0.30
# [t=24972.88] Patient 10528 ARRIVED at exam queue.
# [t=24973.55] Patient 10530 FINISHES service at reception. Duration=3.84
# [t=24973.55] Patient 10532 STARTS service at reception (servers busy=2).
# [t=24973.55] Patient 10530 ARRIVED at testing queue.
# [t=24973.55] Patient 10530 STARTS service at testing (servers busy=1).
# [t=24973.80] Patient 10532 FINISHES service at reception. Duration=0.25
# [t=24973.80] Patient 10532 ARRIVED at exam queue.
# [t=24973.84] Patient 10531 FINISHES service at reception. Duration=1.26
# [t=24973.84] Patient 10531 ARRIVED at testing queue.
# [t=24973.85] Patient 10527 FINISHES service at exam. Duration=3.29
# [t=24973.85] Patient 10528 STARTS service at exam (servers busy=3).
# [t=24973.85] Patient 10527 ARRIVED at payment queue.
# [t=24974.12] Patient 10524 FINISHES service at payment. Duration=2.17
# [t=24974.12] Patient 10526 STARTS service at payment (servers busy=1).
# [t=24974.58] Patient 10526 FINISHES service at payment. Duration=0.46
# [t=24974.58] Patient 10527 STARTS service at payment (servers busy=1).
# [t=24974.60] Patient 10529 FINISHES service at exam. Duration=2.65
# [t=24974.60] Patient 10532 STARTS service at exam (servers busy=3).
# [t=24974.60] Patient 10529 ARRIVED at exam queue.
# [t=24975.41] Patient 10528 FINISHES service at exam. Duration=1.56
# [t=24975.41] Patient 10529 STARTS service at exam (servers busy=3).
# [t=24975.41] Patient 10528 ARRIVED at payment queue.
# [t=24975.75] Patient 10529 FINISHES service at exam. Duration=0.33
# [t=24975.75] Patient 10529 ARRIVED at payment queue.
# [t=24976.21] Patient 10525 FINISHES service at exam. Duration=3.33
# [t=24976.21] Patient 10525 ARRIVED at payment queue.
# [t=24976.63] Patient 10527 FINISHES service at payment. Duration=2.06
# [t=24976.63] Patient 10528 STARTS service at payment (servers busy=1).
# [t=24976.75] Patient 10533 ARRIVED at reception queue.
# [t=24976.75] Patient 10533 STARTS service at reception (servers busy=1).
# [t=24977.20] Patient 10530 FINISHES service at testing. Duration=3.65
# [t=24977.20] Patient 10531 STARTS service at testing (servers busy=1).
# [t=24977.20] Patient 10530 ARRIVED at exam queue.
# [t=24977.20] Patient 10530 STARTS service at exam (servers busy=2).
# [t=24977.58] Patient 10528 FINISHES service at payment. Duration=0.95
# [t=24977.58] Patient 10529 STARTS service at payment (servers busy=1).
# [t=24978.64] Patient 10529 FINISHES service at payment. Duration=1.06
# [t=24978.64] Patient 10525 STARTS service at payment (servers busy=1).
# [t=24979.00] Patient 10534 ARRIVED at reception queue.
# [t=24979.00] Patient 10534 STARTS service at reception (servers busy=2).
# [t=24979.20] Patient 10525 FINISHES service at payment. Duration=0.56
# [t=24979.58] Patient 10531 FINISHES service at testing. Duration=2.38
# [t=24979.58] Patient 10531 ARRIVED at exam queue.
# [t=24979.58] Patient 10531 STARTS service at exam (servers busy=3).
# [t=24980.20] Patient 10531 FINISHES service at exam. Duration=0.62
# [t=24980.20] Patient 10531 ARRIVED at payment queue.
# [t=24980.20] Patient 10531 STARTS service at payment (servers busy=1).
# [t=24980.55] Patient 10534 FINISHES service at reception. Duration=1.55
# [t=24980.55] Patient 10534 ARRIVED at exam queue.
# [t=24980.55] Patient 10534 STARTS service at exam (servers busy=3).
# [t=24980.63] Patient 10531 FINISHES service at payment. Duration=0.44
# [t=24980.87] Patient 10530 FINISHES service at exam. Duration=3.67
# [t=24980.87] Patient 10530 ARRIVED at payment queue.
# [t=24980.87] Patient 10530 STARTS service at payment (servers busy=1).
# [t=24981.13] Patient 10534 FINISHES service at exam. Duration=0.58
# [t=24981.13] Patient 10534 ARRIVED at payment queue.
# [t=24982.09] Patient 10530 FINISHES service at payment. Duration=1.21
# [t=24982.09] Patient 10534 STARTS service at payment (servers busy=1).
# [t=24982.20] Patient 10533 FINISHES service at reception. Duration=5.44
# [t=24982.20] Patient 10533 ARRIVED at exam queue.
# [t=24982.20] Patient 10533 STARTS service at exam (servers busy=2).
# [t=24982.87] Patient 10534 FINISHES service at payment. Duration=0.78
# [t=24982.95] Patient 10535 ARRIVED at reception queue.
# [t=24982.95] Patient 10535 STARTS service at reception (servers busy=1).
# [t=24983.53] Patient 10536 ARRIVED at reception queue.
# [t=24983.53] Patient 10536 STARTS service at reception (servers busy=2).
# [t=24984.52] Patient 10536 FINISHES service at reception. Duration=0.99
# [t=24984.52] Patient 10536 ARRIVED at exam queue.
# [t=24984.52] Patient 10536 STARTS service at exam (servers busy=3).
# [t=24985.14] Patient 10535 FINISHES service at reception. Duration=2.19
# [t=24985.14] Patient 10535 ARRIVED at testing queue.
# [t=24985.14] Patient 10535 STARTS service at testing (servers busy=1).
# [t=24985.25] Patient 10537 ARRIVED at reception queue.
# [t=24985.25] Patient 10537 STARTS service at reception (servers busy=1).
# [t=24987.12] Patient 10532 FINISHES service at exam. Duration=12.51
# [t=24987.12] Patient 10532 ARRIVED at payment queue.
# [t=24987.12] Patient 10532 STARTS service at payment (servers busy=1).
# [t=24987.44] Patient 10536 FINISHES service at exam. Duration=2.92
# [t=24987.44] Patient 10536 ARRIVED at payment queue.
# [t=24987.50] Patient 10538 ARRIVED at reception queue.
# [t=24987.50] Patient 10538 STARTS service at reception (servers busy=2).
# [t=24987.59] Patient 10533 FINISHES service at exam. Duration=5.39
# [t=24987.59] Patient 10533 ARRIVED at payment queue.
# [t=24987.77] Patient 10532 FINISHES service at payment. Duration=0.65
# [t=24987.77] Patient 10536 STARTS service at payment (servers busy=1).
# [t=24988.59] Patient 10535 FINISHES service at testing. Duration=3.44
# [t=24988.59] Patient 10535 ARRIVED at exam queue.
# [t=24988.59] Patient 10535 STARTS service at exam (servers busy=1).
# [t=24988.62] Patient 10538 FINISHES service at reception. Duration=1.12
# [t=24988.62] Patient 10538 ARRIVED at exam queue.
# [t=24988.62] Patient 10538 STARTS service at exam (servers busy=2).
# [t=24989.05] Patient 10537 FINISHES service at reception. Duration=3.79
# [t=24989.05] Patient 10537 ARRIVED at testing queue.
# [t=24989.05] Patient 10537 STARTS service at testing (servers busy=1).
# [t=24989.83] Patient 10535 FINISHES service at exam. Duration=1.24
# [t=24989.83] Patient 10535 ARRIVED at payment queue.
# [t=24990.40] Patient 10536 FINISHES service at payment. Duration=2.63
# [t=24990.40] Patient 10533 STARTS service at payment (servers busy=1).
# [t=24990.92] Patient 10533 FINISHES service at payment. Duration=0.52
# [t=24990.92] Patient 10535 STARTS service at payment (servers busy=1).
# [t=24991.17] Patient 10535 FINISHES service at payment. Duration=0.25
# [t=24991.24] Patient 10539 ARRIVED at reception queue.
# [t=24991.24] Patient 10539 STARTS service at reception (servers busy=1).
# [t=24991.56] Patient 10537 FINISHES service at testing. Duration=2.51
# [t=24991.56] Patient 10537 ARRIVED at exam queue.
# [t=24991.56] Patient 10537 STARTS service at exam (servers busy=2).
# [t=24991.84] Patient 10539 FINISHES service at reception. Duration=0.60
# [t=24991.84] Patient 10539 ARRIVED at exam queue.
# [t=24991.84] Patient 10539 STARTS service at exam (servers busy=3).
# [t=24993.12] Patient 10537 FINISHES service at exam. Duration=1.56
# [t=24993.12] Patient 10537 ARRIVED at payment queue.
# [t=24993.12] Patient 10537 STARTS service at payment (servers busy=1).
# [t=24994.74] Patient 10539 FINISHES service at exam. Duration=2.90
# [t=24994.74] Patient 10539 ARRIVED at payment queue.
# [t=24995.74] Patient 10537 FINISHES service at payment. Duration=2.62
# [t=24995.74] Patient 10539 STARTS service at payment (servers busy=1).
# [t=24995.90] Patient 10539 FINISHES service at payment. Duration=0.16
# [t=24996.69] Patient 10538 FINISHES service at exam. Duration=8.07
# [t=24996.69] Patient 10538 ARRIVED at payment queue.
# [t=24996.69] Patient 10538 STARTS service at payment (servers busy=1).
# [t=24998.01] Patient 10538 FINISHES service at payment. Duration=1.32
# [t=24998.97] Patient 10540 ARRIVED at reception queue.
# [t=24998.97] Patient 10540 STARTS service at reception (servers busy=1).
# [t=24999.40] Patient 10540 FINISHES service at reception. Duration=0.43
# [t=24999.40] Patient 10540 ARRIVED at exam queue.
# [t=24999.40] Patient 10540 STARTS service at exam (servers busy=1).
#
# ================================================================================
#                KẾT QUẢ 3 WORKLOAD – NHÓM NEBULA
# ================================================================================
#    Workload    λ  Số bệnh nhân hoàn thành Thời gian trung bình trong hệ thống Throughput
#  Light load 0.20                     3984                                 9.1    199.200
# Normal load 0.30                     6004                                10.1    300.200
#  Heavy load 0.42                     8418                                13.8    420.900
# ================================================================================

# %% [markdown]
# Workload 1

# %% [markdown]
# Workload 2

# %% [markdown]
# # 5. Conclusions
#
# Project coordinator provide the statements of the work's including the superior point and 2-3 limitation provided by the testing member
